# %%
# 필요한 패키지 임포트
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import warnings 
warnings.filterwarnings('ignore')

# %%
# 데이터 로딩 => dataframe
cust_df = pd.read_csv('../data/santander-customer-satisfaction/train.csv')
test_df = pd.read_csv('../data/santander-customer-satisfaction/test.csv')
# 데이터 구조 확인
print(cust_df.shape)
print(test_df.shape)
# Out:
# (76020, 371)
# (75818, 370)

# %%
# 1. ID feature drop
cust_df.drop('ID', axis=1, inplace=True)
test_df.drop('ID', axis=1, inplace=True)

# %%
X_features = cust_df.iloc[:, :-1] # 데이터 추출
y_labels = cust_df.loc[:, 'TARGET']
print(f'데이터 구조 : {X_features.shape}')
# Out:
# 데이터 구조 : (76020, 369)

# %%
# 의미 없는 feature 찾기 위해 sklearn의 variancethreshold 사용
from sklearn.feature_selection import VarianceThreshold
sel = VarianceThreshold(threshold=0.01)
sel.fit(X_features)
# Out:
# VarianceThreshold(threshold=0.01)

# %%
# 분산도 높은 feature 수
print(sum(sel.get_support()))
# Out:
# 272

# %%
# 분산도 낮은 feature 컬럼 을 X_drop에 저장
X_drop = [x for x in X_features.columns if x not in X_features.columns[sel.get_support()]]

# %%
# 테스트 데이터와 학습데이터에서 분산도 낮은 feature제거 
X_features.drop(X_drop, axis=1, inplace=True)
test_df.drop(X_drop, axis=1, inplace=True)

# %%
# 데이터 구조 확인
X_features.shape, test_df.shape
# Out:
# ((76020, 272), (75818, 272))

# %%
# 상관관계 제거
X_features_copy = X_features.copy()  # 학습 데이터
test_df_copy = test_df.copy() # 테스트 데이터

# 상관계수 행렬 계산
corr_matrix = X_features_copy.corr()

# 상관관계가 높은 피처 찾기
high_corr_var = np.where((corr_matrix > 1) | (corr_matrix < -1))

# 상관관계가 높은 피처 삭제
to_drop = set()  # 삭제할 피처를 저장할 집합

for i in range(len(high_corr_var[0])):
    if high_corr_var[0][i] != high_corr_var[1][i]:  # 같은 피처 쌍은 제외
        # 두 피처 중 하나만 삭제
        to_drop.add(X_features_copy.columns[high_corr_var[1][i]])

# 피처 삭제
X_features_copy.drop(columns=to_drop, inplace=True)
test_df_copy.drop(columns=to_drop, inplace=True)

# 결과 데이터프레임 확인
X_features_drop = X_features_copy
# 테스트 데이터
test_df_drop = test_df_copy

# %%
# 데이터 구조 확인
X_features_drop.shape, test_df_drop.shape
# Out:
# ((76020, 263), (75818, 263))

# %%
# QuantileTransformer
from sklearn.preprocessing import QuantileTransformer

# 학습 데이터
X_features_QT = pd.DataFrame(X_features_drop)
# 테스트 데이터
test_df_QT = pd.DataFrame(test_df_drop)

# 퀀틸트랜스포머 초기화
quantile_transformer = QuantileTransformer(output_distribution='normal')

# 데이터 변환
# 학습 데이터
transformed_data = quantile_transformer.fit_transform(X_features_QT)
# 테스트 데이터
transformed_data_test = quantile_transformer.fit_transform(test_df_QT)

# 학습 데이터
X_features_Q = transformed_data
# 테스트 데이터
test_df_Q = transformed_data_test

# %%
# 데이터 구조 확인
X_features_Q.shape, test_df_Q.shape
# Out:
# ((76020, 263), (75818, 263))

# %%
# 학습/테스트 데이터 분리
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
      X_features_Q
    , y_labels
    , test_size=0.2
    , random_state=0
    , stratify=y_labels
)

# %%
# 조기 종료 => 검증 데이터 분리
X_tr, X_val, y_tr, y_val = train_test_split(
      X_train
    , y_train
    , test_size=0.3
    , random_state=0
    , stratify=y_train
)

# %%
# 학습, 평가 : AUC score
from xgboost import XGBClassifier
from sklearn.metrics import roc_auc_score

# %%
xgb_clf = XGBClassifier(
      n_estimators=800
    , max_depth=5
    , learning_rate=0.01
    , early_stopping_rounds=100
    , eval_metric='auc'
    , random_state=156
)

# %%
# 학습 진행 : fit()
xgb_clf.fit(
      X_tr # 학습할 데이터
    , y_tr # 학습할 답
    , eval_set=[(X_val, y_val)]
)
# 점수 표시
xgb_roc_score = roc_auc_score(y_test, xgb_clf.predict_proba(X_test)[:, 1])
print(f'ROC AUC : {xgb_roc_score:.4f}')
# Out:
# [0]	validation_0-auc:0.82195
# [1]	validation_0-auc:0.82572
# [2]	validation_0-auc:0.82483
# [3]	validation_0-auc:0.82729
# [4]	validation_0-auc:0.82983
# [5]	validation_0-auc:0.83120
# [6]	validation_0-auc:0.83308
# [7]	validation_0-auc:0.83240
# [8]	validation_0-auc:0.83038
# [9]	validation_0-auc:0.83468
# [10]	validation_0-auc:0.83691
# [11]	validation_0-auc:0.83714
# [12]	validation_0-auc:0.83829
# [13]	validation_0-auc:0.83889
# [14]	validation_0-auc:0.83915
# [15]	validation_0-auc:0.83986
# [16]	validation_0-auc:0.84045
# [17]	validation_0-auc:0.84124
# [18]	validation_0-auc:0.84178
# [19]	validation_0-auc:0.84275
# [20]	validation_0-auc:0.84319
# [21]	validation_0-auc:0.84349
# [22]	validation_0-auc:0.84441
# [23]	validation_0-auc:0.84485
# [24]	validation_0-auc:0.84476
# [25]	validation_0-auc:0.84473
# [26]	validation_0-auc:0.84451
# [27]	validation_0-auc:0.84490
# [28]	validation_0-auc:0.84435
# [29]	validation_0-auc:0.84436
# [30]	validation_0-auc:0.84452
# [31]	validation_0-auc:0.84484
# [32]	validation_0-auc:0.84499
# [33]	validation_0-auc:0.84497
# [34]	validation_0-auc:0.84523
# [35]	validation_0-auc:0.84494
# [36]	validation_0-auc:0.84495
# [37]	validation_0-auc:0.84528
# [38]	validation_0-auc:0.84510
# [39]	validation_0-auc:0.84513
# [40]	validation_0-auc:0.84506
# [41]	validation_0-auc:0.84513
# [42]	validation_0-auc:0.84549
# [43]	validation_0-auc:0.84557
# [44]	validation_0-auc:0.84566
# [45]	validation_0-auc:0.84572
# [46]	validation_0-auc:0.84599
# [47]	validation_0-auc:0.84570
# [48]	validation_0-auc:0.84607
# [49]	validation_0-auc:0.84606
# [50]	validation_0-auc:0.84610
# [51]	validation_0-auc:0.84624
# [52]	validation_0-auc:0.84615
# [53]	validation_0-auc:0.84589
# [54]	validation_0-auc:0.84603
# [55]	validation_0-auc:0.84620
# [56]	validation_0-auc:0.84620
# [57]	validation_0-auc:0.84628
# [58]	validation_0-auc:0.84630
# [59]	validation_0-auc:0.84638
# [60]	validation_0-auc:0.84639
# [61]	validation_0-auc:0.84638
# [62]	validation_0-auc:0.84662
# [63]	validation_0-auc:0.84649
# [64]	validation_0-auc:0.84662
# [65]	validation_0-auc:0.84672
# [66]	validation_0-auc:0.84666
# [67]	validation_0-auc:0.84673
# [68]	validation_0-auc:0.84693
# [69]	validation_0-auc:0.84699
# [70]	validation_0-auc:0.84711
# [71]	validation_0-auc:0.84715
# [72]	validation_0-auc:0.84704
# [73]	validation_0-auc:0.84701
# [74]	validation_0-auc:0.84714
# [75]	validation_0-auc:0.84714
# [76]	validation_0-auc:0.84709
# [77]	validation_0-auc:0.84720
# [78]	validation_0-auc:0.84717
# [79]	validation_0-auc:0.84723
# [80]	validation_0-auc:0.84721
# [81]	validation_0-auc:0.84720
# [82]	validation_0-auc:0.84726
# [83]	validation_0-auc:0.84735
# [84]	validation_0-auc:0.84737
# [85]	validation_0-auc:0.84739
# [86]	validation_0-auc:0.84741
# [87]	validation_0-auc:0.84718
# [88]	validation_0-auc:0.84704
# [89]	validation_0-auc:0.84705
# [90]	validation_0-auc:0.84724
# [91]	validation_0-auc:0.84728
# [92]	validation_0-auc:0.84718
# [93]	validation_0-auc:0.84729
# [94]	validation_0-auc:0.84740
# [95]	validation_0-auc:0.84752
# [96]	validation_0-auc:0.84741
# [97]	validation_0-auc:0.84729
# [98]	validation_0-auc:0.84725
# [99]	validation_0-auc:0.84742
# [100]	validation_0-auc:0.84749
# [101]	validation_0-auc:0.84752
# [102]	validation_0-auc:0.84744
# [103]	validation_0-auc:0.84737
# [104]	validation_0-auc:0.84740
# [105]	validation_0-auc:0.84741
# [106]	validation_0-auc:0.84747
# [107]	validation_0-auc:0.84748
# [108]	validation_0-auc:0.84726
# [109]	validation_0-auc:0.84724
# [110]	validation_0-auc:0.84724
# [111]	validation_0-auc:0.84720
# [112]	validation_0-auc:0.84697
# [113]	validation_0-auc:0.84698
# [114]	validation_0-auc:0.84698
# [115]	validation_0-auc:0.84704
# [116]	validation_0-auc:0.84697
# [117]	validation_0-auc:0.84697
# [118]	validation_0-auc:0.84700
# [119]	validation_0-auc:0.84692
# [120]	validation_0-auc:0.84696
# [121]	validation_0-auc:0.84699
# [122]	validation_0-auc:0.84702
# [123]	validation_0-auc:0.84705
# [124]	validation_0-auc:0.84697
# [125]	validation_0-auc:0.84677
# [126]	validation_0-auc:0.84670
# [127]	validation_0-auc:0.84659
# [128]	validation_0-auc:0.84661
# [129]	validation_0-auc:0.84660
# [130]	validation_0-auc:0.84666
# [131]	validation_0-auc:0.84652
# [132]	validation_0-auc:0.84657
# [133]	validation_0-auc:0.84654
# [134]	validation_0-auc:0.84646
# [135]	validation_0-auc:0.84647
# [136]	validation_0-auc:0.84638
# [137]	validation_0-auc:0.84643
# [138]	validation_0-auc:0.84631
# [139]	validation_0-auc:0.84628
# [140]	validation_0-auc:0.84616
# [141]	validation_0-auc:0.84634
# [142]	validation_0-auc:0.84649
# [143]	validation_0-auc:0.84646
# [144]	validation_0-auc:0.84637
# [145]	validation_0-auc:0.84629
# [146]	validation_0-auc:0.84631
# [147]	validation_0-auc:0.84633
# [148]	validation_0-auc:0.84612
# [149]	validation_0-auc:0.84611
# [150]	validation_0-auc:0.84623
# [151]	validation_0-auc:0.84629
# [152]	validation_0-auc:0.84633
# [153]	validation_0-auc:0.84636
# [154]	validation_0-auc:0.84636
# [155]	validation_0-auc:0.84633
# [156]	validation_0-auc:0.84643
# [157]	validation_0-auc:0.84647
# [158]	validation_0-auc:0.84651
# [159]	validation_0-auc:0.84636
# [160]	validation_0-auc:0.84636
# [161]	validation_0-auc:0.84643
# [162]	validation_0-auc:0.84631
# [163]	validation_0-auc:0.84623
# [164]	validation_0-auc:0.84625
# [165]	validation_0-auc:0.84604
# [166]	validation_0-auc:0.84599
# [167]	validation_0-auc:0.84606
# [168]	validation_0-auc:0.84609
# [169]	validation_0-auc:0.84607
# [170]	validation_0-auc:0.84605
# [171]	validation_0-auc:0.84603
# [172]	validation_0-auc:0.84603
# [173]	validation_0-auc:0.84604
# [174]	validation_0-auc:0.84586
# [175]	validation_0-auc:0.84577
# [176]	validation_0-auc:0.84577
# [177]	validation_0-auc:0.84568
# [178]	validation_0-auc:0.84563
# [179]	validation_0-auc:0.84576
# [180]	validation_0-auc:0.84575
# [181]	validation_0-auc:0.84570
# [182]	validation_0-auc:0.84582
# [183]	validation_0-auc:0.84578
# [184]	validation_0-auc:0.84584
# [185]	validation_0-auc:0.84585
# [186]	validation_0-auc:0.84586
# [187]	validation_0-auc:0.84585
# [188]	validation_0-auc:0.84595
# [189]	validation_0-auc:0.84596
# [190]	validation_0-auc:0.84568
# [191]	validation_0-auc:0.84564
# [192]	validation_0-auc:0.84572
# [193]	validation_0-auc:0.84565
# [194]	validation_0-auc:0.84571
# [195]	validation_0-auc:0.84560
# [196]	validation_0-auc:0.84567
# [197]	validation_0-auc:0.84564
# [198]	validation_0-auc:0.84557
# [199]	validation_0-auc:0.84530
# [200]	validation_0-auc:0.84534
# [201]	validation_0-auc:0.84529
# ROC AUC : 0.8230

# %%
# (테스트데이터의 답, 테스트데이터의 예측확률)
xgb_roc_score = roc_auc_score(y_test, xgb_clf.predict_proba(X_test)[:, 1])
print(f'ROC AUC : {xgb_roc_score:.4f}')
# Out:
# ROC AUC : 0.8230

# %%
# hyperopt, KFold 사용한 튜닝
from hyperopt import hp

# max_depth는 1에서 10까지 2간격으로, min_child_weight는 1에서 6까지 1간격으로
# colsample_bytree는 0.5에서 0.95사이, learning_rate는 0.01에서 0.1사이 정규 분포된 값으로 검색. 

xgb_search_space = {'max_depth': hp.quniform('max_depth', 1, 10, 2), 
                    'min_child_weight': hp.quniform('min_child_weight', 1, 6, 1),
                    'colsample_bytree': hp.uniform('colsample_bytree', 0.5, 0.95),
                    'learning_rate': hp.uniform('learning_rate', 0.01, 0.1)
}

# %%
# 데이터 구조 변경
X_train_df = pd.DataFrame(X_train)
y_train_sr = pd.Series(y_train)

# %%
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score

# 목적 함수 설정. 
# 추후 fmin()에서 입력된 search_space값으로 XGBClassifier 교차 검증 학습 후 -1* roc_auc 평균 값을 반환.  
def objective_func(search_space):
    xgb_clf = XGBClassifier(n_estimators=100, max_depth=int(search_space['max_depth']),
                            min_child_weight=int(search_space['min_child_weight']),
                            colsample_bytree=search_space['colsample_bytree'],
                            learning_rate=search_space['learning_rate'],
                            early_stopping_rounds=30,
                            eval_metric='auc'
                           )
    # 2개 k-fold 방식으로 평가된 roc_auc 지표를 담는 list
    roc_auc_list= []
    
    # 2개 k-fold방식 적용 
    kf = KFold(n_splits=3)
    # X_train_over_df을 다시 학습과 검증용 데이터로 분리
    for tr_index, val_index in kf.split(X_train_df):
        # kf.split(X_train_over_df)으로 추출된 학습과 검증 index값으로 학습과 검증 데이터 세트 분리 
        X_tr, y_tr = X_train_df.iloc[tr_index], y_train_sr.iloc[tr_index]
        X_val, y_val = X_train_df.iloc[val_index], y_train_sr.iloc[val_index]
        # early stopping은 30회로 설정하고 추출된 학습과 검증 데이터로 XGBClassifier 학습 수행. 
        xgb_clf.fit(X_tr, y_tr,
                   eval_set=[(X_tr, y_tr), (X_val, y_val)])
    
        # 1로 예측한 확률값 추출후 roc auc 계산하고 평균 roc auc 계산을 위해 list에 결과값 담음. 
        score = roc_auc_score(y_val, xgb_clf.predict_proba(X_val)[:, 1])
        roc_auc_list.append(score)
        
    # 3개 k-fold로 계산된 roc_auc값의 평균값을 반환하되, 
    # HyperOpt는 목적함수의 최소값을 위한 입력값을 찾으므로 -1을 곱한 뒤 반환. 
    return -1 * np.mean(roc_auc_list)

# %%
from hyperopt import fmin, tpe, Trials

trials = Trials()

# fmin()함수를 호출. max_evals지정된 횟수만큼 반복 후 목적함수의 최소값을 가지는 최적 입력값 추출. 
best = fmin(fn=objective_func, space=xgb_search_space, algo=tpe.suggest,
            max_evals=50, # 최대 반복 횟수를 지정합니다.
            trials=trials, rstate=np.random.default_rng(seed=156))

print('best:', best)
# Out:
# [0]	validation_0-auc:0.77925	validation_1-auc:0.75694
# [1]	validation_0-auc:0.83920	validation_1-auc:0.81382
# [2]	validation_0-auc:0.83388	validation_1-auc:0.81077
# [3]	validation_0-auc:0.82972	validation_1-auc:0.80592
# [4]	validation_0-auc:0.82722	validation_1-auc:0.80273
# [5]	validation_0-auc:0.82353	validation_1-auc:0.79582
# [6]	validation_0-auc:0.83619	validation_1-auc:0.80975
# [7]	validation_0-auc:0.83465	validation_1-auc:0.80767
# [8]	validation_0-auc:0.83394	validation_1-auc:0.80585
# [9]	validation_0-auc:0.83884	validation_1-auc:0.81192
# [10]	validation_0-auc:0.84160	validation_1-auc:0.81541
# [11]	validation_0-auc:0.84664	validation_1-auc:0.82118
# [12]	validation_0-auc:0.84885	validation_1-auc:0.82378
# [13]	validation_0-auc:0.85106	validation_1-auc:0.82627
# [14]	validation_0-auc:0.84921	validation_1-auc:0.82450
# [15]	validation_0-auc:0.85224	validation_1-auc:0.82719
# [16]	validation_0-auc:0.85102	validation_1-auc:0.82565
# [17]	validation_0-auc:0.85003	validation_1-auc:0.82504
# [18]	validation_0-auc:0.84885	validation_1-auc:0.82289
# [19]	validation_0-auc:0.85099	validation_1-auc:0.82573
# [20]	validation_0-auc:0.85258	validation_1-auc:0.82716
# [21]	validation_0-auc:0.85374	validation_1-auc:0.82824
# [22]	validation_0-auc:0.85468	validation_1-auc:0.82912
# [23]	validation_0-auc:0.85432	validation_1-auc:0.82856
# [24]	validation_0-auc:0.85547	validation_1-auc:0.82973
# [25]	validation_0-auc:0.85522	validation_1-auc:0.82947
# [26]	validation_0-auc:0.85474	validation_1-auc:0.82882
# [27]	validation_0-auc:0.85399	validation_1-auc:0.82780
# [28]	validation_0-auc:0.85560	validation_1-auc:0.82943
# [29]	validation_0-auc:0.85694	validation_1-auc:0.83056
# [30]	validation_0-auc:0.85653	validation_1-auc:0.82978
# [31]	validation_0-auc:0.85535	validation_1-auc:0.82869
# [32]	validation_0-auc:0.85668	validation_1-auc:0.83052
# [33]	validation_0-auc:0.85768	validation_1-auc:0.83160
# [34]	validation_0-auc:0.85846	validation_1-auc:0.83215
# [35]	validation_0-auc:0.85928	validation_1-auc:0.83284
# [36]	validation_0-auc:0.85981	validation_1-auc:0.83352
# [37]	validation_0-auc:0.85938	validation_1-auc:0.83313
# [38]	validation_0-auc:0.85919	validation_1-auc:0.83261
# [39]	validation_0-auc:0.85987	validation_1-auc:0.83320
# [40]	validation_0-auc:0.85976	validation_1-auc:0.83284
# [41]	validation_0-auc:0.86044	validation_1-auc:0.83365
# [42]	validation_0-auc:0.86091	validation_1-auc:0.83427
# [43]	validation_0-auc:0.86078	validation_1-auc:0.83387
# [44]	validation_0-auc:0.86039	validation_1-auc:0.83327
# [45]	validation_0-auc:0.86089	validation_1-auc:0.83393
# [46]	validation_0-auc:0.86050	validation_1-auc:0.83357
# [47]	validation_0-auc:0.86016	validation_1-auc:0.83317
# [48]	validation_0-auc:0.86055	validation_1-auc:0.83354
# [49]	validation_0-auc:0.86104	validation_1-auc:0.83397
# [50]	validation_0-auc:0.86156	validation_1-auc:0.83430
# [51]	validation_0-auc:0.86186	validation_1-auc:0.83449
# [52]	validation_0-auc:0.86228	validation_1-auc:0.83507
# [53]	validation_0-auc:0.86263	validation_1-auc:0.83544
# [54]	validation_0-auc:0.86295	validation_1-auc:0.83569
# [55]	validation_0-auc:0.86332	validation_1-auc:0.83615
# [56]	validation_0-auc:0.86336	validation_1-auc:0.83612
# [57]	validation_0-auc:0.86342	validation_1-auc:0.83594
# [58]	validation_0-auc:0.86390	validation_1-auc:0.83649
# [59]	validation_0-auc:0.86441	validation_1-auc:0.83682
# [60]	validation_0-auc:0.86472	validation_1-auc:0.83701
# [61]	validation_0-auc:0.86508	validation_1-auc:0.83730
# [62]	validation_0-auc:0.86555	validation_1-auc:0.83757
# [63]	validation_0-auc:0.86597	validation_1-auc:0.83791
# [64]	validation_0-auc:0.86598	validation_1-auc:0.83777
# [65]	validation_0-auc:0.86596	validation_1-auc:0.83794
# [66]	validation_0-auc:0.86618	validation_1-auc:0.83800
# [67]	validation_0-auc:0.86661	validation_1-auc:0.83812
# [68]	validation_0-auc:0.86664	validation_1-auc:0.83814
# [69]	validation_0-auc:0.86658	validation_1-auc:0.83796
# [70]	validation_0-auc:0.86706	validation_1-auc:0.83808
# [71]	validation_0-auc:0.86703	validation_1-auc:0.83789
# [72]	validation_0-auc:0.86718	validation_1-auc:0.83781
# [73]	validation_0-auc:0.86762	validation_1-auc:0.83790
# [74]	validation_0-auc:0.86772	validation_1-auc:0.83776
# [75]	validation_0-auc:0.86793	validation_1-auc:0.83795
# [76]	validation_0-auc:0.86828	validation_1-auc:0.83815
# [77]	validation_0-auc:0.86867	validation_1-auc:0.83839
# [78]	validation_0-auc:0.86885	validation_1-auc:0.83851
# [79]	validation_0-auc:0.86915	validation_1-auc:0.83867
# [80]	validation_0-auc:0.86937	validation_1-auc:0.83887
# [81]	validation_0-auc:0.86944	validation_1-auc:0.83860
# [82]	validation_0-auc:0.86924	validation_1-auc:0.83844
# [83]	validation_0-auc:0.86927	validation_1-auc:0.83827
# [84]	validation_0-auc:0.86930	validation_1-auc:0.83826
# [85]	validation_0-auc:0.86957	validation_1-auc:0.83839
# [86]	validation_0-auc:0.86990	validation_1-auc:0.83867
# [87]	validation_0-auc:0.87017	validation_1-auc:0.83898
# [88]	validation_0-auc:0.87052	validation_1-auc:0.83906
# [89]	validation_0-auc:0.87073	validation_1-auc:0.83919
# [90]	validation_0-auc:0.87103	validation_1-auc:0.83925
# [91]	validation_0-auc:0.87112	validation_1-auc:0.83906
# [92]	validation_0-auc:0.87149	validation_1-auc:0.83930
# [93]	validation_0-auc:0.87164	validation_1-auc:0.83948
# [94]	validation_0-auc:0.87187	validation_1-auc:0.83956
# [95]	validation_0-auc:0.87200	validation_1-auc:0.83942
# [96]	validation_0-auc:0.87222	validation_1-auc:0.83981
# [97]	validation_0-auc:0.87234	validation_1-auc:0.83968
# [98]	validation_0-auc:0.87242	validation_1-auc:0.83966
# [99]	validation_0-auc:0.87262	validation_1-auc:0.83967
# [0]	validation_0-auc:0.77754	validation_1-auc:0.74073
# [1]	validation_0-auc:0.84139	validation_1-auc:0.81203
# [2]	validation_0-auc:0.83803	validation_1-auc:0.80522
# [3]	validation_0-auc:0.83876	validation_1-auc:0.80276
# [4]	validation_0-auc:0.83520	validation_1-auc:0.79948
# [5]	validation_0-auc:0.83490	validation_1-auc:0.79801
# [6]	validation_0-auc:0.84442	validation_1-auc:0.80699
# [7]	validation_0-auc:0.84372	validation_1-auc:0.80600
# [8]	validation_0-auc:0.84268	validation_1-auc:0.80507
# [9]	validation_0-auc:0.84707	validation_1-auc:0.81070
# [10]	validation_0-auc:0.85024	validation_1-auc:0.81369
# [11]	validation_0-auc:0.85371	validation_1-auc:0.81841
# [12]	validation_0-auc:0.85599	validation_1-auc:0.82214
# [13]	validation_0-auc:0.85735	validation_1-auc:0.82388
# [14]	validation_0-auc:0.85652	validation_1-auc:0.82316
# [15]	validation_0-auc:0.85806	validation_1-auc:0.82433
# [16]	validation_0-auc:0.85724	validation_1-auc:0.82295
# [17]	validation_0-auc:0.85650	validation_1-auc:0.82154
# [18]	validation_0-auc:0.85533	validation_1-auc:0.82112
# [19]	validation_0-auc:0.85659	validation_1-auc:0.82245
# [20]	validation_0-auc:0.85776	validation_1-auc:0.82364
# [21]	validation_0-auc:0.85873	validation_1-auc:0.82498
# [22]	validation_0-auc:0.85950	validation_1-auc:0.82583
# [23]	validation_0-auc:0.85903	validation_1-auc:0.82499
# [24]	validation_0-auc:0.86022	validation_1-auc:0.82607
# [25]	validation_0-auc:0.85958	validation_1-auc:0.82508
# [26]	validation_0-auc:0.85889	validation_1-auc:0.82428
# [27]	validation_0-auc:0.85835	validation_1-auc:0.82392
# [28]	validation_0-auc:0.85930	validation_1-auc:0.82448
# [29]	validation_0-auc:0.86006	validation_1-auc:0.82519
# [30]	validation_0-auc:0.85956	validation_1-auc:0.82462
# [31]	validation_0-auc:0.85896	validation_1-auc:0.82432
# [32]	validation_0-auc:0.86002	validation_1-auc:0.82533
# [33]	validation_0-auc:0.86085	validation_1-auc:0.82639
# [34]	validation_0-auc:0.86162	validation_1-auc:0.82721
# [35]	validation_0-auc:0.86221	validation_1-auc:0.82765
# [36]	validation_0-auc:0.86285	validation_1-auc:0.82806
# [37]	validation_0-auc:0.86288	validation_1-auc:0.82785
# [38]	validation_0-auc:0.86259	validation_1-auc:0.82737
# [39]	validation_0-auc:0.86314	validation_1-auc:0.82769
# [40]	validation_0-auc:0.86324	validation_1-auc:0.82763
# [41]	validation_0-auc:0.86375	validation_1-auc:0.82781
# [42]	validation_0-auc:0.86423	validation_1-auc:0.82808
# [43]	validation_0-auc:0.86388	validation_1-auc:0.82760
# [44]	validation_0-auc:0.86369	validation_1-auc:0.82716
# [45]	validation_0-auc:0.86457	validation_1-auc:0.82803
# [46]	validation_0-auc:0.86444	validation_1-auc:0.82767
# [47]	validation_0-auc:0.86394	validation_1-auc:0.82719
# [48]	validation_0-auc:0.86479	validation_1-auc:0.82788
# [49]	validation_0-auc:0.86562	validation_1-auc:0.82847
# [50]	validation_0-auc:0.86641	validation_1-auc:0.82918
# [51]	validation_0-auc:0.86696	validation_1-auc:0.82964
# [52]	validation_0-auc:0.86770	validation_1-auc:0.83053
# [53]	validation_0-auc:0.86796	validation_1-auc:0.83097
# [54]	validation_0-auc:0.86833	validation_1-auc:0.83134
# [55]	validation_0-auc:0.86873	validation_1-auc:0.83157
# [56]	validation_0-auc:0.86864	validation_1-auc:0.83123
# [57]	validation_0-auc:0.86880	validation_1-auc:0.83111
# [58]	validation_0-auc:0.86936	validation_1-auc:0.83153
# [59]	validation_0-auc:0.86965	validation_1-auc:0.83191
# [60]	validation_0-auc:0.86991	validation_1-auc:0.83210
# [61]	validation_0-auc:0.87045	validation_1-auc:0.83230
# [62]	validation_0-auc:0.87094	validation_1-auc:0.83256
# [63]	validation_0-auc:0.87126	validation_1-auc:0.83268
# [64]	validation_0-auc:0.87110	validation_1-auc:0.83234
# [65]	validation_0-auc:0.87105	validation_1-auc:0.83195
# [66]	validation_0-auc:0.87126	validation_1-auc:0.83227
# [67]	validation_0-auc:0.87174	validation_1-auc:0.83240
# [68]	validation_0-auc:0.87174	validation_1-auc:0.83235
# [69]	validation_0-auc:0.87157	validation_1-auc:0.83231
# [70]	validation_0-auc:0.87212	validation_1-auc:0.83254
# [71]	validation_0-auc:0.87194	validation_1-auc:0.83237
# [72]	validation_0-auc:0.87192	validation_1-auc:0.83235
# [73]	validation_0-auc:0.87235	validation_1-auc:0.83254
# [74]	validation_0-auc:0.87226	validation_1-auc:0.83237
# [75]	validation_0-auc:0.87284	validation_1-auc:0.83270
# [76]	validation_0-auc:0.87321	validation_1-auc:0.83299
# [77]	validation_0-auc:0.87346	validation_1-auc:0.83327
# [78]	validation_0-auc:0.87356	validation_1-auc:0.83349
# [79]	validation_0-auc:0.87388	validation_1-auc:0.83387
# [80]	validation_0-auc:0.87416	validation_1-auc:0.83398
# [81]	validation_0-auc:0.87429	validation_1-auc:0.83403
# [82]	validation_0-auc:0.87445	validation_1-auc:0.83404
# [83]	validation_0-auc:0.87467	validation_1-auc:0.83405
# [84]	validation_0-auc:0.87463	validation_1-auc:0.83377
# [85]	validation_0-auc:0.87498	validation_1-auc:0.83406
# [86]	validation_0-auc:0.87524	validation_1-auc:0.83428
# [87]	validation_0-auc:0.87559	validation_1-auc:0.83457
# [88]	validation_0-auc:0.87585	validation_1-auc:0.83470
# [89]	validation_0-auc:0.87608	validation_1-auc:0.83480
# [90]	validation_0-auc:0.87640	validation_1-auc:0.83479
# [91]	validation_0-auc:0.87668	validation_1-auc:0.83486
# [92]	validation_0-auc:0.87695	validation_1-auc:0.83491
# [93]	validation_0-auc:0.87720	validation_1-auc:0.83508
# [94]	validation_0-auc:0.87751	validation_1-auc:0.83516
# [95]	validation_0-auc:0.87754	validation_1-auc:0.83520
# [96]	validation_0-auc:0.87780	validation_1-auc:0.83544
# [97]	validation_0-auc:0.87794	validation_1-auc:0.83536
# [98]	validation_0-auc:0.87806	validation_1-auc:0.83540
# [99]	validation_0-auc:0.87838	validation_1-auc:0.83524
# [0]	validation_0-auc:0.77873	validation_1-auc:0.74517
# [1]	validation_0-auc:0.83413	validation_1-auc:0.80720
# [2]	validation_0-auc:0.83354	validation_1-auc:0.80573
# [3]	validation_0-auc:0.82762	validation_1-auc:0.80002
# [4]	validation_0-auc:0.82256	validation_1-auc:0.79464
# [5]	validation_0-auc:0.82266	validation_1-auc:0.79466
# [6]	validation_0-auc:0.83367	validation_1-auc:0.81009
# [7]	validation_0-auc:0.83244	validation_1-auc:0.80686
# [8]	validation_0-auc:0.83099	validation_1-auc:0.80407
# [9]	validation_0-auc:0.83688	validation_1-auc:0.81165
# [10]	validation_0-auc:0.84209	validation_1-auc:0.81730
# [11]	validation_0-auc:0.84679	validation_1-auc:0.82252
# [12]	validation_0-auc:0.84973	validation_1-auc:0.82653
# [13]	validation_0-auc:0.85084	validation_1-auc:0.82855
# [14]	validation_0-auc:0.85039	validation_1-auc:0.82786
# [15]	validation_0-auc:0.85204	validation_1-auc:0.82921
# [16]	validation_0-auc:0.85115	validation_1-auc:0.82735
# [17]	validation_0-auc:0.85052	validation_1-auc:0.82590
# [18]	validation_0-auc:0.84979	validation_1-auc:0.82434
# [19]	validation_0-auc:0.85130	validation_1-auc:0.82565
# [20]	validation_0-auc:0.85199	validation_1-auc:0.82686
# [21]	validation_0-auc:0.85251	validation_1-auc:0.82824
# [22]	validation_0-auc:0.85358	validation_1-auc:0.82935
# [23]	validation_0-auc:0.85319	validation_1-auc:0.82831
# [24]	validation_0-auc:0.85399	validation_1-auc:0.82949
# [25]	validation_0-auc:0.85316	validation_1-auc:0.82799
# [26]	validation_0-auc:0.85236	validation_1-auc:0.82705
# [27]	validation_0-auc:0.85220	validation_1-auc:0.82627
# [28]	validation_0-auc:0.85377	validation_1-auc:0.82772
# [29]	validation_0-auc:0.85458	validation_1-auc:0.82861
# [30]	validation_0-auc:0.85458	validation_1-auc:0.82803
# [31]	validation_0-auc:0.85433	validation_1-auc:0.82756
# [32]	validation_0-auc:0.85491	validation_1-auc:0.82838
# [33]	validation_0-auc:0.85590	validation_1-auc:0.82958
# [34]	validation_0-auc:0.85649	validation_1-auc:0.83025
# [35]	validation_0-auc:0.85708	validation_1-auc:0.83121
# [36]	validation_0-auc:0.85779	validation_1-auc:0.83187
# [37]	validation_0-auc:0.85733	validation_1-auc:0.83095
# [38]	validation_0-auc:0.85688	validation_1-auc:0.82999
# [39]	validation_0-auc:0.85775	validation_1-auc:0.83085
# [40]	validation_0-auc:0.85728	validation_1-auc:0.82999
# [41]	validation_0-auc:0.85801	validation_1-auc:0.83073
# [42]	validation_0-auc:0.85881	validation_1-auc:0.83134
# [43]	validation_0-auc:0.85855	validation_1-auc:0.83059
# [44]	validation_0-auc:0.85820	validation_1-auc:0.82942
# [45]	validation_0-auc:0.85925	validation_1-auc:0.83060
# [46]	validation_0-auc:0.85888	validation_1-auc:0.83004
# [47]	validation_0-auc:0.85843	validation_1-auc:0.82922
# [48]	validation_0-auc:0.85937	validation_1-auc:0.83008
# [49]	validation_0-auc:0.86015	validation_1-auc:0.83091
# [50]	validation_0-auc:0.86078	validation_1-auc:0.83136
# [51]	validation_0-auc:0.86127	validation_1-auc:0.83185
# [52]	validation_0-auc:0.86183	validation_1-auc:0.83238
# [53]	validation_0-auc:0.86241	validation_1-auc:0.83276
# [54]	validation_0-auc:0.86278	validation_1-auc:0.83314
# [55]	validation_0-auc:0.86332	validation_1-auc:0.83354
# [56]	validation_0-auc:0.86309	validation_1-auc:0.83314
# [57]	validation_0-auc:0.86313	validation_1-auc:0.83299
# [58]	validation_0-auc:0.86378	validation_1-auc:0.83347
# [59]	validation_0-auc:0.86429	validation_1-auc:0.83380
# [60]	validation_0-auc:0.86486	validation_1-auc:0.83453
# [61]	validation_0-auc:0.86548	validation_1-auc:0.83488
# [62]	validation_0-auc:0.86585	validation_1-auc:0.83505
# [63]	validation_0-auc:0.86626	validation_1-auc:0.83543
# [64]	validation_0-auc:0.86615	validation_1-auc:0.83489
# [65]	validation_0-auc:0.86599	validation_1-auc:0.83431
# [66]	validation_0-auc:0.86632	validation_1-auc:0.83470
# [67]	validation_0-auc:0.86670	validation_1-auc:0.83490
# [68]	validation_0-auc:0.86674	validation_1-auc:0.83497
# [69]	validation_0-auc:0.86635	validation_1-auc:0.83448
# [70]	validation_0-auc:0.86683	validation_1-auc:0.83487
# [71]	validation_0-auc:0.86669	validation_1-auc:0.83447
# [72]	validation_0-auc:0.86695	validation_1-auc:0.83435
# [73]	validation_0-auc:0.86742	validation_1-auc:0.83487
# [74]	validation_0-auc:0.86757	validation_1-auc:0.83458
# [75]	validation_0-auc:0.86805	validation_1-auc:0.83499
# [76]	validation_0-auc:0.86855	validation_1-auc:0.83543
# [77]	validation_0-auc:0.86898	validation_1-auc:0.83599
# [78]	validation_0-auc:0.86934	validation_1-auc:0.83636
# [79]	validation_0-auc:0.86970	validation_1-auc:0.83664
# [80]	validation_0-auc:0.86995	validation_1-auc:0.83699
# [81]	validation_0-auc:0.87008	validation_1-auc:0.83688
# [82]	validation_0-auc:0.87002	validation_1-auc:0.83649
# [83]	validation_0-auc:0.87008	validation_1-auc:0.83623
# [84]	validation_0-auc:0.86998	validation_1-auc:0.83575
# [85]	validation_0-auc:0.87038	validation_1-auc:0.83615
# [86]	validation_0-auc:0.87070	validation_1-auc:0.83661
# [87]	validation_0-auc:0.87115	validation_1-auc:0.83693
# [88]	validation_0-auc:0.87170	validation_1-auc:0.83721
# [89]	validation_0-auc:0.87193	validation_1-auc:0.83771
# [90]	validation_0-auc:0.87224	validation_1-auc:0.83793
# [91]	validation_0-auc:0.87240	validation_1-auc:0.83753
# [92]	validation_0-auc:0.87276	validation_1-auc:0.83786
# [93]	validation_0-auc:0.87301	validation_1-auc:0.83807
# [94]	validation_0-auc:0.87326	validation_1-auc:0.83844
# [95]	validation_0-auc:0.87333	validation_1-auc:0.83815
# [96]	validation_0-auc:0.87369	validation_1-auc:0.83860
# [97]	validation_0-auc:0.87367	validation_1-auc:0.83827
# [98]	validation_0-auc:0.87363	validation_1-auc:0.83797
# [99]	validation_0-auc:0.87387	validation_1-auc:0.83780
# [0]	validation_0-auc:0.84094	validation_1-auc:0.81851
# [1]	validation_0-auc:0.84398	validation_1-auc:0.82020
# [2]	validation_0-auc:0.84523	validation_1-auc:0.82198
# [3]	validation_0-auc:0.84591	validation_1-auc:0.82218
# [4]	validation_0-auc:0.84589	validation_1-auc:0.82266
# [5]	validation_0-auc:0.84668	validation_1-auc:0.82340
# [6]	validation_0-auc:0.84650	validation_1-auc:0.82354
# [7]	validation_0-auc:0.84792	validation_1-auc:0.82453
# [8]	validation_0-auc:0.84850	validation_1-auc:0.82488
# [9]	validation_0-auc:0.84896	validation_1-auc:0.82511
# [10]	validation_0-auc:0.84939	validation_1-auc:0.82568
# [11]	validation_0-auc:0.84999	validation_1-auc:0.82678
# [12]	validation_0-auc:0.85014	validation_1-auc:0.82678
# [13]	validation_0-auc:0.85096	validation_1-auc:0.82720
# [14]	validation_0-auc:0.85160	validation_1-auc:0.82781
# [15]	validation_0-auc:0.85194	validation_1-auc:0.82763
# [16]	validation_0-auc:0.85242	validation_1-auc:0.82741
# [17]	validation_0-auc:0.85465	validation_1-auc:0.83015
# [18]	validation_0-auc:0.85522	validation_1-auc:0.83035
# [19]	validation_0-auc:0.85677	validation_1-auc:0.83224
# [20]	validation_0-auc:0.85714	validation_1-auc:0.83236
# [21]	validation_0-auc:0.85790	validation_1-auc:0.83249
# [22]	validation_0-auc:0.85873	validation_1-auc:0.83318
# [23]	validation_0-auc:0.85929	validation_1-auc:0.83345
# [24]	validation_0-auc:0.85984	validation_1-auc:0.83427
# [25]	validation_0-auc:0.86027	validation_1-auc:0.83449
# [26]	validation_0-auc:0.86060	validation_1-auc:0.83425
# [27]	validation_0-auc:0.86112	validation_1-auc:0.83486
# [28]	validation_0-auc:0.86146	validation_1-auc:0.83506
# [29]	validation_0-auc:0.86178	validation_1-auc:0.83509
# [30]	validation_0-auc:0.86208	validation_1-auc:0.83603
# [31]	validation_0-auc:0.86242	validation_1-auc:0.83646
# [32]	validation_0-auc:0.86275	validation_1-auc:0.83661
# [33]	validation_0-auc:0.86315	validation_1-auc:0.83649
# [34]	validation_0-auc:0.86384	validation_1-auc:0.83625
# [35]	validation_0-auc:0.86430	validation_1-auc:0.83633
# [36]	validation_0-auc:0.86458	validation_1-auc:0.83637
# [37]	validation_0-auc:0.86500	validation_1-auc:0.83681
# [38]	validation_0-auc:0.86518	validation_1-auc:0.83696
# [39]	validation_0-auc:0.86524	validation_1-auc:0.83710
# [40]	validation_0-auc:0.86553	validation_1-auc:0.83716
# [41]	validation_0-auc:0.86579	validation_1-auc:0.83727
# [42]	validation_0-auc:0.86607	validation_1-auc:0.83760
# [43]	validation_0-auc:0.86621	validation_1-auc:0.83755
# [44]	validation_0-auc:0.86641	validation_1-auc:0.83769
# [45]	validation_0-auc:0.86659	validation_1-auc:0.83786
# [46]	validation_0-auc:0.86689	validation_1-auc:0.83798
# [47]	validation_0-auc:0.86719	validation_1-auc:0.83814
# [48]	validation_0-auc:0.86732	validation_1-auc:0.83818
# [49]	validation_0-auc:0.86771	validation_1-auc:0.83821
# [50]	validation_0-auc:0.86795	validation_1-auc:0.83842
# [51]	validation_0-auc:0.86820	validation_1-auc:0.83847
# [52]	validation_0-auc:0.86835	validation_1-auc:0.83843
# [53]	validation_0-auc:0.86859	validation_1-auc:0.83847
# [54]	validation_0-auc:0.86885	validation_1-auc:0.83870
# [55]	validation_0-auc:0.86907	validation_1-auc:0.83861
# [56]	validation_0-auc:0.86926	validation_1-auc:0.83875
# [57]	validation_0-auc:0.86951	validation_1-auc:0.83922
# [58]	validation_0-auc:0.86980	validation_1-auc:0.83911
# [59]	validation_0-auc:0.87021	validation_1-auc:0.83935
# [60]	validation_0-auc:0.87062	validation_1-auc:0.83942
# [61]	validation_0-auc:0.87091	validation_1-auc:0.83954
# [62]	validation_0-auc:0.87123	validation_1-auc:0.83974
# [63]	validation_0-auc:0.87153	validation_1-auc:0.83994
# [64]	validation_0-auc:0.87179	validation_1-auc:0.84002
# [65]	validation_0-auc:0.87208	validation_1-auc:0.84013
# [66]	validation_0-auc:0.87250	validation_1-auc:0.84027
# [67]	validation_0-auc:0.87291	validation_1-auc:0.84051
# [68]	validation_0-auc:0.87317	validation_1-auc:0.84065
# [69]	validation_0-auc:0.87357	validation_1-auc:0.84066
# [70]	validation_0-auc:0.87380	validation_1-auc:0.84056
# [71]	validation_0-auc:0.87400	validation_1-auc:0.84056
# [72]	validation_0-auc:0.87447	validation_1-auc:0.84059
# [73]	validation_0-auc:0.87474	validation_1-auc:0.84063
# [74]	validation_0-auc:0.87507	validation_1-auc:0.84080
# [75]	validation_0-auc:0.87539	validation_1-auc:0.84081
# [76]	validation_0-auc:0.87550	validation_1-auc:0.84076
# [77]	validation_0-auc:0.87574	validation_1-auc:0.84078
# [78]	validation_0-auc:0.87606	validation_1-auc:0.84092
# [79]	validation_0-auc:0.87630	validation_1-auc:0.84098
# [80]	validation_0-auc:0.87668	validation_1-auc:0.84128
# [81]	validation_0-auc:0.87692	validation_1-auc:0.84131
# [82]	validation_0-auc:0.87720	validation_1-auc:0.84148
# [83]	validation_0-auc:0.87755	validation_1-auc:0.84168
# [84]	validation_0-auc:0.87784	validation_1-auc:0.84174
# [85]	validation_0-auc:0.87807	validation_1-auc:0.84183
# [86]	validation_0-auc:0.87841	validation_1-auc:0.84196
# [87]	validation_0-auc:0.87861	validation_1-auc:0.84210
# [88]	validation_0-auc:0.87888	validation_1-auc:0.84203
# [89]	validation_0-auc:0.87910	validation_1-auc:0.84210
# [90]	validation_0-auc:0.87938	validation_1-auc:0.84216
# [91]	validation_0-auc:0.87955	validation_1-auc:0.84229
# [92]	validation_0-auc:0.87983	validation_1-auc:0.84235
# [93]	validation_0-auc:0.88014	validation_1-auc:0.84238
# [94]	validation_0-auc:0.88049	validation_1-auc:0.84248
# [95]	validation_0-auc:0.88071	validation_1-auc:0.84254
# [96]	validation_0-auc:0.88087	validation_1-auc:0.84259
# [97]	validation_0-auc:0.88103	validation_1-auc:0.84269
# [98]	validation_0-auc:0.88109	validation_1-auc:0.84276
# [99]	validation_0-auc:0.88123	validation_1-auc:0.84276
# [0]	validation_0-auc:0.84502	validation_1-auc:0.81931
# [1]	validation_0-auc:0.84519	validation_1-auc:0.81915
# [2]	validation_0-auc:0.84533	validation_1-auc:0.81905
# [3]	validation_0-auc:0.84736	validation_1-auc:0.82214
# [4]	validation_0-auc:0.84813	validation_1-auc:0.82234
# [5]	validation_0-auc:0.84972	validation_1-auc:0.82285
# [6]	validation_0-auc:0.84980	validation_1-auc:0.82253
# [7]	validation_0-auc:0.85062	validation_1-auc:0.82301
# [8]	validation_0-auc:0.85076	validation_1-auc:0.82335
# [9]	validation_0-auc:0.85106	validation_1-auc:0.82364
# [10]	validation_0-auc:0.85166	validation_1-auc:0.82421
# [11]	validation_0-auc:0.85193	validation_1-auc:0.82464
# [12]	validation_0-auc:0.85257	validation_1-auc:0.82484
# [13]	validation_0-auc:0.85312	validation_1-auc:0.82477
# [14]	validation_0-auc:0.85405	validation_1-auc:0.82538
# [15]	validation_0-auc:0.85456	validation_1-auc:0.82555
# [16]	validation_0-auc:0.85477	validation_1-auc:0.82553
# [17]	validation_0-auc:0.85783	validation_1-auc:0.82769
# [18]	validation_0-auc:0.85863	validation_1-auc:0.82861
# [19]	validation_0-auc:0.85959	validation_1-auc:0.82998
# [20]	validation_0-auc:0.85971	validation_1-auc:0.82984
# [21]	validation_0-auc:0.85995	validation_1-auc:0.82960
# [22]	validation_0-auc:0.86010	validation_1-auc:0.82938
# [23]	validation_0-auc:0.86029	validation_1-auc:0.82942
# [24]	validation_0-auc:0.86032	validation_1-auc:0.82940
# [25]	validation_0-auc:0.86156	validation_1-auc:0.83033
# [26]	validation_0-auc:0.86244	validation_1-auc:0.83103
# [27]	validation_0-auc:0.86279	validation_1-auc:0.83163
# [28]	validation_0-auc:0.86365	validation_1-auc:0.83204
# [29]	validation_0-auc:0.86438	validation_1-auc:0.83275
# [30]	validation_0-auc:0.86491	validation_1-auc:0.83305
# [31]	validation_0-auc:0.86565	validation_1-auc:0.83363
# [32]	validation_0-auc:0.86623	validation_1-auc:0.83413
# [33]	validation_0-auc:0.86663	validation_1-auc:0.83433
# [34]	validation_0-auc:0.86709	validation_1-auc:0.83454
# [35]	validation_0-auc:0.86755	validation_1-auc:0.83470
# [36]	validation_0-auc:0.86817	validation_1-auc:0.83483
# [37]	validation_0-auc:0.86860	validation_1-auc:0.83516
# [38]	validation_0-auc:0.86889	validation_1-auc:0.83526
# [39]	validation_0-auc:0.86919	validation_1-auc:0.83507
# [40]	validation_0-auc:0.86959	validation_1-auc:0.83516
# [41]	validation_0-auc:0.86979	validation_1-auc:0.83547
# [42]	validation_0-auc:0.87009	validation_1-auc:0.83557
# [43]	validation_0-auc:0.87052	validation_1-auc:0.83559
# [44]	validation_0-auc:0.87088	validation_1-auc:0.83545
# [45]	validation_0-auc:0.87122	validation_1-auc:0.83525
# [46]	validation_0-auc:0.87163	validation_1-auc:0.83554
# [47]	validation_0-auc:0.87201	validation_1-auc:0.83578
# [48]	validation_0-auc:0.87226	validation_1-auc:0.83582
# [49]	validation_0-auc:0.87243	validation_1-auc:0.83591
# [50]	validation_0-auc:0.87279	validation_1-auc:0.83627
# [51]	validation_0-auc:0.87317	validation_1-auc:0.83651
# [52]	validation_0-auc:0.87348	validation_1-auc:0.83682
# [53]	validation_0-auc:0.87368	validation_1-auc:0.83703
# [54]	validation_0-auc:0.87391	validation_1-auc:0.83716
# [55]	validation_0-auc:0.87427	validation_1-auc:0.83726
# [56]	validation_0-auc:0.87461	validation_1-auc:0.83739
# [57]	validation_0-auc:0.87534	validation_1-auc:0.83767
# [58]	validation_0-auc:0.87554	validation_1-auc:0.83775
# [59]	validation_0-auc:0.87567	validation_1-auc:0.83795
# [60]	validation_0-auc:0.87585	validation_1-auc:0.83792
# [61]	validation_0-auc:0.87611	validation_1-auc:0.83781
# [62]	validation_0-auc:0.87624	validation_1-auc:0.83779
# [63]	validation_0-auc:0.87643	validation_1-auc:0.83782
# [64]	validation_0-auc:0.87659	validation_1-auc:0.83775
# [65]	validation_0-auc:0.87686	validation_1-auc:0.83761
# [66]	validation_0-auc:0.87701	validation_1-auc:0.83764
# [67]	validation_0-auc:0.87726	validation_1-auc:0.83777
# [68]	validation_0-auc:0.87763	validation_1-auc:0.83766
# [69]	validation_0-auc:0.87772	validation_1-auc:0.83757
# [70]	validation_0-auc:0.87800	validation_1-auc:0.83769
# [71]	validation_0-auc:0.87816	validation_1-auc:0.83766
# [72]	validation_0-auc:0.87830	validation_1-auc:0.83764
# [73]	validation_0-auc:0.87872	validation_1-auc:0.83744
# [74]	validation_0-auc:0.87917	validation_1-auc:0.83750
# [75]	validation_0-auc:0.87954	validation_1-auc:0.83759
# [76]	validation_0-auc:0.87975	validation_1-auc:0.83758
# [77]	validation_0-auc:0.87997	validation_1-auc:0.83768
# [78]	validation_0-auc:0.88019	validation_1-auc:0.83769
# [79]	validation_0-auc:0.88056	validation_1-auc:0.83763
# [80]	validation_0-auc:0.88079	validation_1-auc:0.83772
# [81]	validation_0-auc:0.88094	validation_1-auc:0.83777
# [82]	validation_0-auc:0.88121	validation_1-auc:0.83795
# [83]	validation_0-auc:0.88149	validation_1-auc:0.83806
# [84]	validation_0-auc:0.88168	validation_1-auc:0.83807
# [85]	validation_0-auc:0.88191	validation_1-auc:0.83822
# [86]	validation_0-auc:0.88198	validation_1-auc:0.83827
# [87]	validation_0-auc:0.88222	validation_1-auc:0.83830
# [88]	validation_0-auc:0.88237	validation_1-auc:0.83833
# [89]	validation_0-auc:0.88258	validation_1-auc:0.83834
# [90]	validation_0-auc:0.88274	validation_1-auc:0.83827
# [91]	validation_0-auc:0.88285	validation_1-auc:0.83825
# [92]	validation_0-auc:0.88296	validation_1-auc:0.83823
# [93]	validation_0-auc:0.88311	validation_1-auc:0.83829
# [94]	validation_0-auc:0.88332	validation_1-auc:0.83841
# [95]	validation_0-auc:0.88349	validation_1-auc:0.83850
# [96]	validation_0-auc:0.88368	validation_1-auc:0.83845
# [97]	validation_0-auc:0.88385	validation_1-auc:0.83840
# [98]	validation_0-auc:0.88394	validation_1-auc:0.83843
# [99]	validation_0-auc:0.88404	validation_1-auc:0.83845
# [0]	validation_0-auc:0.84093	validation_1-auc:0.82920
# [1]	validation_0-auc:0.84335	validation_1-auc:0.83016
# [2]	validation_0-auc:0.84337	validation_1-auc:0.82947
# [3]	validation_0-auc:0.84457	validation_1-auc:0.83028
# [4]	validation_0-auc:0.84476	validation_1-auc:0.83063
# [5]	validation_0-auc:0.84567	validation_1-auc:0.83099
# [6]	validation_0-auc:0.84572	validation_1-auc:0.83148
# [7]	validation_0-auc:0.84571	validation_1-auc:0.83178
# [8]	validation_0-auc:0.84599	validation_1-auc:0.83237
# [9]	validation_0-auc:0.84623	validation_1-auc:0.83239
# [10]	validation_0-auc:0.84646	validation_1-auc:0.83280
# [11]	validation_0-auc:0.84695	validation_1-auc:0.83264
# [12]	validation_0-auc:0.84754	validation_1-auc:0.83372
# [13]	validation_0-auc:0.84771	validation_1-auc:0.83349
# [14]	validation_0-auc:0.84861	validation_1-auc:0.83452
# [15]	validation_0-auc:0.84880	validation_1-auc:0.83442
# [16]	validation_0-auc:0.84934	validation_1-auc:0.83479
# [17]	validation_0-auc:0.85124	validation_1-auc:0.83566
# [18]	validation_0-auc:0.85248	validation_1-auc:0.83714
# [19]	validation_0-auc:0.85372	validation_1-auc:0.83779
# [20]	validation_0-auc:0.85421	validation_1-auc:0.83791
# [21]	validation_0-auc:0.85440	validation_1-auc:0.83804
# [22]	validation_0-auc:0.85453	validation_1-auc:0.83815
# [23]	validation_0-auc:0.85462	validation_1-auc:0.83830
# [24]	validation_0-auc:0.85477	validation_1-auc:0.83821
# [25]	validation_0-auc:0.85522	validation_1-auc:0.83820
# [26]	validation_0-auc:0.85541	validation_1-auc:0.83834
# [27]	validation_0-auc:0.85606	validation_1-auc:0.83895
# [28]	validation_0-auc:0.85754	validation_1-auc:0.83961
# [29]	validation_0-auc:0.85815	validation_1-auc:0.83992
# [30]	validation_0-auc:0.85866	validation_1-auc:0.84047
# [31]	validation_0-auc:0.85967	validation_1-auc:0.84067
# [32]	validation_0-auc:0.86029	validation_1-auc:0.84069
# [33]	validation_0-auc:0.86087	validation_1-auc:0.84074
# [34]	validation_0-auc:0.86139	validation_1-auc:0.84089
# [35]	validation_0-auc:0.86168	validation_1-auc:0.84100
# [36]	validation_0-auc:0.86216	validation_1-auc:0.84127
# [37]	validation_0-auc:0.86262	validation_1-auc:0.84107
# [38]	validation_0-auc:0.86336	validation_1-auc:0.84124
# [39]	validation_0-auc:0.86395	validation_1-auc:0.84140
# [40]	validation_0-auc:0.86438	validation_1-auc:0.84143
# [41]	validation_0-auc:0.86473	validation_1-auc:0.84151
# [42]	validation_0-auc:0.86514	validation_1-auc:0.84138
# [43]	validation_0-auc:0.86548	validation_1-auc:0.84155
# [44]	validation_0-auc:0.86569	validation_1-auc:0.84137
# [45]	validation_0-auc:0.86599	validation_1-auc:0.84125
# [46]	validation_0-auc:0.86645	validation_1-auc:0.84118
# [47]	validation_0-auc:0.86691	validation_1-auc:0.84126
# [48]	validation_0-auc:0.86727	validation_1-auc:0.84113
# [49]	validation_0-auc:0.86755	validation_1-auc:0.84120
# [50]	validation_0-auc:0.86779	validation_1-auc:0.84118
# [51]	validation_0-auc:0.86797	validation_1-auc:0.84109
# [52]	validation_0-auc:0.86822	validation_1-auc:0.84107
# [53]	validation_0-auc:0.86857	validation_1-auc:0.84121
# [54]	validation_0-auc:0.86889	validation_1-auc:0.84118
# [55]	validation_0-auc:0.86906	validation_1-auc:0.84113
# [56]	validation_0-auc:0.86949	validation_1-auc:0.84121
# [57]	validation_0-auc:0.87025	validation_1-auc:0.84139
# [58]	validation_0-auc:0.87061	validation_1-auc:0.84121
# [59]	validation_0-auc:0.87090	validation_1-auc:0.84126
# [60]	validation_0-auc:0.87117	validation_1-auc:0.84147
# [61]	validation_0-auc:0.87157	validation_1-auc:0.84151
# [62]	validation_0-auc:0.87188	validation_1-auc:0.84138
# [63]	validation_0-auc:0.87227	validation_1-auc:0.84133
# [64]	validation_0-auc:0.87263	validation_1-auc:0.84135
# [65]	validation_0-auc:0.87296	validation_1-auc:0.84122
# [66]	validation_0-auc:0.87319	validation_1-auc:0.84119
# [67]	validation_0-auc:0.87340	validation_1-auc:0.84105
# [68]	validation_0-auc:0.87355	validation_1-auc:0.84102
# [69]	validation_0-auc:0.87377	validation_1-auc:0.84107
# [70]	validation_0-auc:0.87408	validation_1-auc:0.84096
# [71]	validation_0-auc:0.87440	validation_1-auc:0.84110
# [72]	validation_0-auc:0.87482	validation_1-auc:0.84094
# [0]	validation_0-auc:0.86038	validation_1-auc:0.81543
# [1]	validation_0-auc:0.86724	validation_1-auc:0.82429
# [2]	validation_0-auc:0.87323	validation_1-auc:0.82306
# [3]	validation_0-auc:0.87731	validation_1-auc:0.82528
# [4]	validation_0-auc:0.88146	validation_1-auc:0.82980
# [5]	validation_0-auc:0.88497	validation_1-auc:0.83001
# [6]	validation_0-auc:0.88660	validation_1-auc:0.82942
# [7]	validation_0-auc:0.88768	validation_1-auc:0.82817
# [8]	validation_0-auc:0.89051	validation_1-auc:0.83031
# [9]	validation_0-auc:0.89396	validation_1-auc:0.83193
# [10]	validation_0-auc:0.89539	validation_1-auc:0.83256
# [11]	validation_0-auc:0.89760	validation_1-auc:0.83232
# [12]	validation_0-auc:0.89975	validation_1-auc:0.83288
# [13]	validation_0-auc:0.90084	validation_1-auc:0.83322
# [14]	validation_0-auc:0.90231	validation_1-auc:0.83383
# [15]	validation_0-auc:0.90429	validation_1-auc:0.83410
# [16]	validation_0-auc:0.90578	validation_1-auc:0.83479
# [17]	validation_0-auc:0.90689	validation_1-auc:0.83417
# [18]	validation_0-auc:0.90820	validation_1-auc:0.83601
# [19]	validation_0-auc:0.90956	validation_1-auc:0.83629
# [20]	validation_0-auc:0.91101	validation_1-auc:0.83581
# [21]	validation_0-auc:0.91188	validation_1-auc:0.83564
# [22]	validation_0-auc:0.91329	validation_1-auc:0.83588
# [23]	validation_0-auc:0.91459	validation_1-auc:0.83598
# [24]	validation_0-auc:0.91593	validation_1-auc:0.83599
# [25]	validation_0-auc:0.91710	validation_1-auc:0.83591
# [26]	validation_0-auc:0.91836	validation_1-auc:0.83535
# [27]	validation_0-auc:0.91972	validation_1-auc:0.83480
# [28]	validation_0-auc:0.92072	validation_1-auc:0.83451
# [29]	validation_0-auc:0.92148	validation_1-auc:0.83470
# [30]	validation_0-auc:0.92247	validation_1-auc:0.83447
# [31]	validation_0-auc:0.92343	validation_1-auc:0.83519
# [32]	validation_0-auc:0.92396	validation_1-auc:0.83597
# [33]	validation_0-auc:0.92455	validation_1-auc:0.83622
# [34]	validation_0-auc:0.92558	validation_1-auc:0.83605
# [35]	validation_0-auc:0.92617	validation_1-auc:0.83609
# [36]	validation_0-auc:0.92676	validation_1-auc:0.83628
# [37]	validation_0-auc:0.92743	validation_1-auc:0.83653
# [38]	validation_0-auc:0.92834	validation_1-auc:0.83638
# [39]	validation_0-auc:0.92861	validation_1-auc:0.83685
# [40]	validation_0-auc:0.92906	validation_1-auc:0.83704
# [41]	validation_0-auc:0.92927	validation_1-auc:0.83710
# [42]	validation_0-auc:0.92934	validation_1-auc:0.83725
# [43]	validation_0-auc:0.92976	validation_1-auc:0.83718
# [44]	validation_0-auc:0.92993	validation_1-auc:0.83728
# [45]	validation_0-auc:0.93011	validation_1-auc:0.83739
# [46]	validation_0-auc:0.93059	validation_1-auc:0.83780
# [47]	validation_0-auc:0.93080	validation_1-auc:0.83784
# [48]	validation_0-auc:0.93148	validation_1-auc:0.83785
# [49]	validation_0-auc:0.93169	validation_1-auc:0.83783
# [50]	validation_0-auc:0.93207	validation_1-auc:0.83788
# [51]	validation_0-auc:0.93232	validation_1-auc:0.83768
# [52]	validation_0-auc:0.93254	validation_1-auc:0.83766
# [53]	validation_0-auc:0.93273	validation_1-auc:0.83759
# [54]	validation_0-auc:0.93320	validation_1-auc:0.83731
# [55]	validation_0-auc:0.93327	validation_1-auc:0.83736
# [56]	validation_0-auc:0.93343	validation_1-auc:0.83723
# [57]	validation_0-auc:0.93358	validation_1-auc:0.83726
# [58]	validation_0-auc:0.93424	validation_1-auc:0.83791
# [59]	validation_0-auc:0.93436	validation_1-auc:0.83791
# [60]	validation_0-auc:0.93470	validation_1-auc:0.83790
# [61]	validation_0-auc:0.93520	validation_1-auc:0.83786
# [62]	validation_0-auc:0.93533	validation_1-auc:0.83775
# [63]	validation_0-auc:0.93551	validation_1-auc:0.83776
# [64]	validation_0-auc:0.93561	validation_1-auc:0.83769
# [65]	validation_0-auc:0.93575	validation_1-auc:0.83763
# [66]	validation_0-auc:0.93590	validation_1-auc:0.83755
# [67]	validation_0-auc:0.93603	validation_1-auc:0.83756
# [68]	validation_0-auc:0.93637	validation_1-auc:0.83763
# [69]	validation_0-auc:0.93652	validation_1-auc:0.83777
# [70]	validation_0-auc:0.93674	validation_1-auc:0.83768
# [71]	validation_0-auc:0.93678	validation_1-auc:0.83764
# [72]	validation_0-auc:0.93719	validation_1-auc:0.83735
# [73]	validation_0-auc:0.93738	validation_1-auc:0.83737
# [74]	validation_0-auc:0.93751	validation_1-auc:0.83719
# [75]	validation_0-auc:0.93769	validation_1-auc:0.83716
# [76]	validation_0-auc:0.93775	validation_1-auc:0.83722
# [77]	validation_0-auc:0.93788	validation_1-auc:0.83718
# [78]	validation_0-auc:0.93799	validation_1-auc:0.83703
# [79]	validation_0-auc:0.93810	validation_1-auc:0.83714
# [80]	validation_0-auc:0.93839	validation_1-auc:0.83693
# [81]	validation_0-auc:0.93872	validation_1-auc:0.83694
# [82]	validation_0-auc:0.93879	validation_1-auc:0.83683
# [83]	validation_0-auc:0.93893	validation_1-auc:0.83687
# [84]	validation_0-auc:0.93954	validation_1-auc:0.83672
# [85]	validation_0-auc:0.93968	validation_1-auc:0.83664
# [86]	validation_0-auc:0.93981	validation_1-auc:0.83662
# [87]	validation_0-auc:0.93999	validation_1-auc:0.83646
# [0]	validation_0-auc:0.86888	validation_1-auc:0.81165
# [1]	validation_0-auc:0.87130	validation_1-auc:0.81812
# [2]	validation_0-auc:0.87768	validation_1-auc:0.81775
# [3]	validation_0-auc:0.88147	validation_1-auc:0.82128
# [4]	validation_0-auc:0.88696	validation_1-auc:0.82354
# [5]	validation_0-auc:0.88855	validation_1-auc:0.82553
# [6]	validation_0-auc:0.88970	validation_1-auc:0.82636
# [7]	validation_0-auc:0.89078	validation_1-auc:0.82519
# [8]	validation_0-auc:0.89354	validation_1-auc:0.82651
# [9]	validation_0-auc:0.89644	validation_1-auc:0.82715
# [10]	validation_0-auc:0.89970	validation_1-auc:0.82868
# [11]	validation_0-auc:0.90066	validation_1-auc:0.82912
# [12]	validation_0-auc:0.90143	validation_1-auc:0.82880
# [13]	validation_0-auc:0.90479	validation_1-auc:0.83028
# [14]	validation_0-auc:0.90619	validation_1-auc:0.83017
# [15]	validation_0-auc:0.90745	validation_1-auc:0.83027
# [16]	validation_0-auc:0.90880	validation_1-auc:0.83032
# [17]	validation_0-auc:0.91044	validation_1-auc:0.82928
# [18]	validation_0-auc:0.91210	validation_1-auc:0.82981
# [19]	validation_0-auc:0.91279	validation_1-auc:0.83085
# [20]	validation_0-auc:0.91436	validation_1-auc:0.83107
# [21]	validation_0-auc:0.91573	validation_1-auc:0.83166
# [22]	validation_0-auc:0.91667	validation_1-auc:0.83178
# ...
# [11]	validation_0-auc:0.80148	validation_1-auc:0.79744
# [12]	validation_0-auc:0.80157	validation_1-auc:0.79754
# [13]	validation_0-auc:0.80536	validation_1-auc:0.79952
# [14]	validation_0-auc:0.80607	validation_1-auc:0.79987
# [15]	validation_0-auc:0.80558	validation_1-auc:0.79967
# [16]	validation_0-auc:0.80774	validation_1-auc:0.80120
# [17]	validation_0-auc:0.82113	validation_1-auc:0.81320
# [18]	validation_0-auc:0.82102	validation_1-auc:0.81240
# [19]	validation_0-auc:0.82075	validation_1-auc:0.81285
# [20]	validation_0-auc:0.82079	validation_1-auc:0.81273
# [21]	validation_0-auc:0.82293	validation_1-auc:0.81420
# [22]	validation_0-auc:0.82296	validation_1-auc:0.81414
# [23]	validation_0-auc:0.82490	validation_1-auc:0.81565
# [24]	validation_0-auc:0.82611	validation_1-auc:0.81723
# [25]	validation_0-auc:0.82568	validation_1-auc:0.81650
# [26]	validation_0-auc:0.82656	validation_1-auc:0.81677
# [27]	validation_0-auc:0.82720	validation_1-auc:0.81778
# [28]	validation_0-auc:0.82865	validation_1-auc:0.81949
# [29]	validation_0-auc:0.83086	validation_1-auc:0.82121
# [30]	validation_0-auc:0.83197	validation_1-auc:0.82130
# [31]	validation_0-auc:0.83266	validation_1-auc:0.82216
# [32]	validation_0-auc:0.83315	validation_1-auc:0.82291
# [33]	validation_0-auc:0.83311	validation_1-auc:0.82290
# [34]	validation_0-auc:0.83371	validation_1-auc:0.82248
# [35]	validation_0-auc:0.83391	validation_1-auc:0.82280
# [36]	validation_0-auc:0.83520	validation_1-auc:0.82390
# [37]	validation_0-auc:0.83627	validation_1-auc:0.82519
# [38]	validation_0-auc:0.83639	validation_1-auc:0.82531
# [39]	validation_0-auc:0.83677	validation_1-auc:0.82505
# [40]	validation_0-auc:0.83776	validation_1-auc:0.82621
# [41]	validation_0-auc:0.83844	validation_1-auc:0.82701
# [42]	validation_0-auc:0.83862	validation_1-auc:0.82701
# [43]	validation_0-auc:0.83905	validation_1-auc:0.82744
# [44]	validation_0-auc:0.83925	validation_1-auc:0.82825
# [45]	validation_0-auc:0.83993	validation_1-auc:0.82890
# [46]	validation_0-auc:0.84019	validation_1-auc:0.82904
# [47]	validation_0-auc:0.84077	validation_1-auc:0.82964
# [48]	validation_0-auc:0.84177	validation_1-auc:0.83080
# [49]	validation_0-auc:0.84205	validation_1-auc:0.83079
# [50]	validation_0-auc:0.84265	validation_1-auc:0.83118
# [51]	validation_0-auc:0.84286	validation_1-auc:0.83129
# [52]	validation_0-auc:0.84313	validation_1-auc:0.83126
# [53]	validation_0-auc:0.84365	validation_1-auc:0.83144
# [54]	validation_0-auc:0.84412	validation_1-auc:0.83161
# [55]	validation_0-auc:0.84442	validation_1-auc:0.83184
# [56]	validation_0-auc:0.84480	validation_1-auc:0.83195
# [57]	validation_0-auc:0.84521	validation_1-auc:0.83236
# [58]	validation_0-auc:0.84527	validation_1-auc:0.83249
# [59]	validation_0-auc:0.84560	validation_1-auc:0.83269
# [60]	validation_0-auc:0.84576	validation_1-auc:0.83295
# [61]	validation_0-auc:0.84586	validation_1-auc:0.83305
# [62]	validation_0-auc:0.84635	validation_1-auc:0.83349
# [63]	validation_0-auc:0.84684	validation_1-auc:0.83358
# [64]	validation_0-auc:0.84694	validation_1-auc:0.83364
# [65]	validation_0-auc:0.84722	validation_1-auc:0.83409
# [66]	validation_0-auc:0.84740	validation_1-auc:0.83423
# [67]	validation_0-auc:0.84764	validation_1-auc:0.83421
# [68]	validation_0-auc:0.84779	validation_1-auc:0.83411
# [69]	validation_0-auc:0.84811	validation_1-auc:0.83429
# [70]	validation_0-auc:0.84836	validation_1-auc:0.83456
# [71]	validation_0-auc:0.84859	validation_1-auc:0.83459
# [72]	validation_0-auc:0.84873	validation_1-auc:0.83473
# [73]	validation_0-auc:0.84888	validation_1-auc:0.83483
# [74]	validation_0-auc:0.84904	validation_1-auc:0.83480
# [75]	validation_0-auc:0.84907	validation_1-auc:0.83464
# [76]	validation_0-auc:0.84933	validation_1-auc:0.83477
# [77]	validation_0-auc:0.84959	validation_1-auc:0.83488
# [78]	validation_0-auc:0.84967	validation_1-auc:0.83489
# [79]	validation_0-auc:0.84986	validation_1-auc:0.83504
# [80]	validation_0-auc:0.85016	validation_1-auc:0.83510
# [81]	validation_0-auc:0.85039	validation_1-auc:0.83527
# [82]	validation_0-auc:0.85065	validation_1-auc:0.83536
# [83]	validation_0-auc:0.85069	validation_1-auc:0.83532
# [84]	validation_0-auc:0.85089	validation_1-auc:0.83548
# [85]	validation_0-auc:0.85099	validation_1-auc:0.83564
# [86]	validation_0-auc:0.85107	validation_1-auc:0.83567
# [87]	validation_0-auc:0.85124	validation_1-auc:0.83584
# [88]	validation_0-auc:0.85137	validation_1-auc:0.83576
# [89]	validation_0-auc:0.85156	validation_1-auc:0.83582
# [90]	validation_0-auc:0.85172	validation_1-auc:0.83581
# [91]	validation_0-auc:0.85193	validation_1-auc:0.83585
# [92]	validation_0-auc:0.85194	validation_1-auc:0.83583
# [93]	validation_0-auc:0.85213	validation_1-auc:0.83599
# [94]	validation_0-auc:0.85235	validation_1-auc:0.83616
# [95]	validation_0-auc:0.85243	validation_1-auc:0.83620
# [96]	validation_0-auc:0.85261	validation_1-auc:0.83608
# [97]	validation_0-auc:0.85285	validation_1-auc:0.83609
# [98]	validation_0-auc:0.85314	validation_1-auc:0.83635
# [99]	validation_0-auc:0.85325	validation_1-auc:0.83635
# [0]	validation_0-auc:0.77317	validation_1-auc:0.78218
# [1]	validation_0-auc:0.77317	validation_1-auc:0.78218
# [2]	validation_0-auc:0.77410	validation_1-auc:0.78272
# [3]	validation_0-auc:0.77410	validation_1-auc:0.78272
# [4]	validation_0-auc:0.77410	validation_1-auc:0.78272
# [5]	validation_0-auc:0.77478	validation_1-auc:0.78340
# [6]	validation_0-auc:0.77943	validation_1-auc:0.78578
# [7]	validation_0-auc:0.77943	validation_1-auc:0.78578
# [8]	validation_0-auc:0.77943	validation_1-auc:0.78578
# [9]	validation_0-auc:0.78541	validation_1-auc:0.78947
# [10]	validation_0-auc:0.80260	validation_1-auc:0.80551
# [11]	validation_0-auc:0.80324	validation_1-auc:0.80607
# [12]	validation_0-auc:0.80344	validation_1-auc:0.80645
# [13]	validation_0-auc:0.80895	validation_1-auc:0.80633
# [14]	validation_0-auc:0.80870	validation_1-auc:0.80605
# [15]	validation_0-auc:0.80866	validation_1-auc:0.80621
# [16]	validation_0-auc:0.80797	validation_1-auc:0.80556
# [17]	validation_0-auc:0.82107	validation_1-auc:0.81563
# [18]	validation_0-auc:0.82076	validation_1-auc:0.81594
# [19]	validation_0-auc:0.82148	validation_1-auc:0.81684
# [20]	validation_0-auc:0.82285	validation_1-auc:0.81946
# [21]	validation_0-auc:0.82335	validation_1-auc:0.82161
# [22]	validation_0-auc:0.82525	validation_1-auc:0.82389
# [23]	validation_0-auc:0.82466	validation_1-auc:0.82336
# [24]	validation_0-auc:0.82596	validation_1-auc:0.82501
# [25]	validation_0-auc:0.82682	validation_1-auc:0.82646
# [26]	validation_0-auc:0.82682	validation_1-auc:0.82571
# [27]	validation_0-auc:0.82670	validation_1-auc:0.82596
# [28]	validation_0-auc:0.82743	validation_1-auc:0.82683
# [29]	validation_0-auc:0.82770	validation_1-auc:0.82678
# [30]	validation_0-auc:0.82894	validation_1-auc:0.82765
# [31]	validation_0-auc:0.82947	validation_1-auc:0.82772
# [32]	validation_0-auc:0.82939	validation_1-auc:0.82753
# [33]	validation_0-auc:0.83056	validation_1-auc:0.82902
# [34]	validation_0-auc:0.83118	validation_1-auc:0.82957
# [35]	validation_0-auc:0.83184	validation_1-auc:0.83040
# [36]	validation_0-auc:0.83260	validation_1-auc:0.83164
# [37]	validation_0-auc:0.83372	validation_1-auc:0.83199
# [38]	validation_0-auc:0.83371	validation_1-auc:0.83212
# [39]	validation_0-auc:0.83433	validation_1-auc:0.83299
# [40]	validation_0-auc:0.83436	validation_1-auc:0.83286
# [41]	validation_0-auc:0.83488	validation_1-auc:0.83324
# [42]	validation_0-auc:0.83564	validation_1-auc:0.83389
# [43]	validation_0-auc:0.83638	validation_1-auc:0.83454
# [44]	validation_0-auc:0.83657	validation_1-auc:0.83443
# [45]	validation_0-auc:0.83723	validation_1-auc:0.83485
# [46]	validation_0-auc:0.83755	validation_1-auc:0.83514
# [47]	validation_0-auc:0.83794	validation_1-auc:0.83546
# [48]	validation_0-auc:0.83847	validation_1-auc:0.83577
# [49]	validation_0-auc:0.83895	validation_1-auc:0.83651
# [50]	validation_0-auc:0.83919	validation_1-auc:0.83697
# [51]	validation_0-auc:0.83971	validation_1-auc:0.83731
# [52]	validation_0-auc:0.83995	validation_1-auc:0.83756
# [53]	validation_0-auc:0.84043	validation_1-auc:0.83780
# [54]	validation_0-auc:0.84065	validation_1-auc:0.83797
# [55]	validation_0-auc:0.84088	validation_1-auc:0.83812
# [56]	validation_0-auc:0.84107	validation_1-auc:0.83848
# [57]	validation_0-auc:0.84153	validation_1-auc:0.83895
# [58]	validation_0-auc:0.84165	validation_1-auc:0.83917
# [59]	validation_0-auc:0.84206	validation_1-auc:0.83940
# [60]	validation_0-auc:0.84216	validation_1-auc:0.83956
# [61]	validation_0-auc:0.84236	validation_1-auc:0.83942
# [62]	validation_0-auc:0.84250	validation_1-auc:0.83961
# [63]	validation_0-auc:0.84262	validation_1-auc:0.83974
# [64]	validation_0-auc:0.84269	validation_1-auc:0.83962
# [65]	validation_0-auc:0.84286	validation_1-auc:0.83987
# [66]	validation_0-auc:0.84305	validation_1-auc:0.84012
# [67]	validation_0-auc:0.84338	validation_1-auc:0.84060
# [68]	validation_0-auc:0.84369	validation_1-auc:0.84071
# [69]	validation_0-auc:0.84396	validation_1-auc:0.84088
# [70]	validation_0-auc:0.84408	validation_1-auc:0.84099
# [71]	validation_0-auc:0.84432	validation_1-auc:0.84099
# [72]	validation_0-auc:0.84451	validation_1-auc:0.84103
# [73]	validation_0-auc:0.84466	validation_1-auc:0.84122
# [74]	validation_0-auc:0.84497	validation_1-auc:0.84136
# [75]	validation_0-auc:0.84509	validation_1-auc:0.84129
# [76]	validation_0-auc:0.84528	validation_1-auc:0.84123
# [77]	validation_0-auc:0.84535	validation_1-auc:0.84122
# [78]	validation_0-auc:0.84544	validation_1-auc:0.84125
# [79]	validation_0-auc:0.84553	validation_1-auc:0.84145
# [80]	validation_0-auc:0.84572	validation_1-auc:0.84152
# [81]	validation_0-auc:0.84588	validation_1-auc:0.84154
# [82]	validation_0-auc:0.84603	validation_1-auc:0.84152
# [83]	validation_0-auc:0.84617	validation_1-auc:0.84163
# [84]	validation_0-auc:0.84632	validation_1-auc:0.84171
# [85]	validation_0-auc:0.84648	validation_1-auc:0.84165
# [86]	validation_0-auc:0.84657	validation_1-auc:0.84170
# [87]	validation_0-auc:0.84677	validation_1-auc:0.84159
# [88]	validation_0-auc:0.84689	validation_1-auc:0.84169
# [89]	validation_0-auc:0.84699	validation_1-auc:0.84190
# [90]	validation_0-auc:0.84714	validation_1-auc:0.84185
# [91]	validation_0-auc:0.84728	validation_1-auc:0.84187
# [92]	validation_0-auc:0.84751	validation_1-auc:0.84195
# [93]	validation_0-auc:0.84756	validation_1-auc:0.84207
# [94]	validation_0-auc:0.84785	validation_1-auc:0.84215
# [95]	validation_0-auc:0.84794	validation_1-auc:0.84208
# [96]	validation_0-auc:0.84821	validation_1-auc:0.84226
# [97]	validation_0-auc:0.84841	validation_1-auc:0.84248
# [98]	validation_0-auc:0.84863	validation_1-auc:0.84260
# [99]	validation_0-auc:0.84879	validation_1-auc:0.84262
# 100%|██████████| 50/50 [16:00<00:00, 19.21s/trial, best loss: -0.8441764768076493]
# best: {'colsample_bytree': np.float64(0.8242619585971493), 'learning_rate': np.float64(0.08431814420718546), 'max_depth': np.float64(4.0), 'min_child_weight': np.float64(3.0)}

# %%
best= {'colsample_bytree': np.float64(0.8242619585971493)
       , 'learning_rate': np.float64(0.08431814420718546)
       , 'max_depth': np.float64(4.0)
       , 'min_child_weight': np.float64(3.0)}

# %%
xgb_clf =  XGBClassifier(
                        n_estimators=500,
                        max_depth=int(best['max_depth']),
                        min_child_weight=int(best['min_child_weight']), 
                        colsample_bytree=best['colsample_bytree'],
                        learning_rate=best['learning_rate'],
                        early_stopping_rounds=100, 
                        eval_metric="auc"
                        )

# evaluation metric을 auc로, early stopping은 100 으로 설정하고 학습 수행. 
xgb_clf.fit(X_tr, y_tr,eval_set=[(X_tr, y_tr), (X_val, y_val)])

xgb_roc_score = roc_auc_score(y_test, xgb_clf.predict_proba(X_test)[:,1])
print('ROC AUC: {0:.4f}'.format(xgb_roc_score))
# Out:
# [0]	validation_0-auc:0.82056	validation_1-auc:0.82084
# [1]	validation_0-auc:0.82483	validation_1-auc:0.82538
# [2]	validation_0-auc:0.82599	validation_1-auc:0.82339
# [3]	validation_0-auc:0.83005	validation_1-auc:0.82681
# [4]	validation_0-auc:0.83371	validation_1-auc:0.82924
# [5]	validation_0-auc:0.83456	validation_1-auc:0.83078
# [6]	validation_0-auc:0.83541	validation_1-auc:0.83270
# [7]	validation_0-auc:0.83778	validation_1-auc:0.83227
# [8]	validation_0-auc:0.83479	validation_1-auc:0.83027
# [9]	validation_0-auc:0.83907	validation_1-auc:0.83446
# [10]	validation_0-auc:0.84173	validation_1-auc:0.83675
# [11]	validation_0-auc:0.84280	validation_1-auc:0.83702
# [12]	validation_0-auc:0.84456	validation_1-auc:0.83817
# [13]	validation_0-auc:0.84543	validation_1-auc:0.83886
# [14]	validation_0-auc:0.84516	validation_1-auc:0.83891
# [15]	validation_0-auc:0.84632	validation_1-auc:0.83967
# [16]	validation_0-auc:0.84689	validation_1-auc:0.84043
# [17]	validation_0-auc:0.84700	validation_1-auc:0.84105
# [18]	validation_0-auc:0.84733	validation_1-auc:0.84127
# [19]	validation_0-auc:0.84842	validation_1-auc:0.84152
# [20]	validation_0-auc:0.84925	validation_1-auc:0.84186
# [21]	validation_0-auc:0.84993	validation_1-auc:0.84219
# [22]	validation_0-auc:0.85023	validation_1-auc:0.84304
# [23]	validation_0-auc:0.85169	validation_1-auc:0.84299
# [24]	validation_0-auc:0.85230	validation_1-auc:0.84301
# [25]	validation_0-auc:0.85251	validation_1-auc:0.84345
# [26]	validation_0-auc:0.85262	validation_1-auc:0.84350
# [27]	validation_0-auc:0.85336	validation_1-auc:0.84366
# [28]	validation_0-auc:0.85385	validation_1-auc:0.84338
# [29]	validation_0-auc:0.85449	validation_1-auc:0.84353
# [30]	validation_0-auc:0.85526	validation_1-auc:0.84338
# [31]	validation_0-auc:0.85559	validation_1-auc:0.84407
# [32]	validation_0-auc:0.85588	validation_1-auc:0.84427
# [33]	validation_0-auc:0.85612	validation_1-auc:0.84480
# [34]	validation_0-auc:0.85663	validation_1-auc:0.84478
# [35]	validation_0-auc:0.85691	validation_1-auc:0.84506
# [36]	validation_0-auc:0.85724	validation_1-auc:0.84482
# [37]	validation_0-auc:0.85793	validation_1-auc:0.84543
# [38]	validation_0-auc:0.85838	validation_1-auc:0.84537
# [39]	validation_0-auc:0.85862	validation_1-auc:0.84524
# [40]	validation_0-auc:0.85888	validation_1-auc:0.84557
# [41]	validation_0-auc:0.85927	validation_1-auc:0.84557
# [42]	validation_0-auc:0.85967	validation_1-auc:0.84557
# [43]	validation_0-auc:0.86036	validation_1-auc:0.84562
# [44]	validation_0-auc:0.86071	validation_1-auc:0.84588
# [45]	validation_0-auc:0.86086	validation_1-auc:0.84611
# [46]	validation_0-auc:0.86149	validation_1-auc:0.84633
# [47]	validation_0-auc:0.86183	validation_1-auc:0.84627
# [48]	validation_0-auc:0.86217	validation_1-auc:0.84642
# [49]	validation_0-auc:0.86249	validation_1-auc:0.84640
# [50]	validation_0-auc:0.86272	validation_1-auc:0.84637
# [51]	validation_0-auc:0.86299	validation_1-auc:0.84633
# [52]	validation_0-auc:0.86324	validation_1-auc:0.84632
# [53]	validation_0-auc:0.86365	validation_1-auc:0.84636
# [54]	validation_0-auc:0.86381	validation_1-auc:0.84649
# [55]	validation_0-auc:0.86427	validation_1-auc:0.84655
# [56]	validation_0-auc:0.86483	validation_1-auc:0.84662
# [57]	validation_0-auc:0.86527	validation_1-auc:0.84684
# [58]	validation_0-auc:0.86553	validation_1-auc:0.84672
# [59]	validation_0-auc:0.86573	validation_1-auc:0.84691
# [60]	validation_0-auc:0.86598	validation_1-auc:0.84679
# [61]	validation_0-auc:0.86659	validation_1-auc:0.84717
# [62]	validation_0-auc:0.86682	validation_1-auc:0.84728
# [63]	validation_0-auc:0.86706	validation_1-auc:0.84720
# [64]	validation_0-auc:0.86736	validation_1-auc:0.84729
# [65]	validation_0-auc:0.86753	validation_1-auc:0.84734
# [66]	validation_0-auc:0.86810	validation_1-auc:0.84762
# [67]	validation_0-auc:0.86818	validation_1-auc:0.84763
# [68]	validation_0-auc:0.86828	validation_1-auc:0.84770
# [69]	validation_0-auc:0.86841	validation_1-auc:0.84783
# [70]	validation_0-auc:0.86861	validation_1-auc:0.84760
# [71]	validation_0-auc:0.86874	validation_1-auc:0.84769
# [72]	validation_0-auc:0.86880	validation_1-auc:0.84784
# [73]	validation_0-auc:0.86896	validation_1-auc:0.84781
# [74]	validation_0-auc:0.86904	validation_1-auc:0.84784
# [75]	validation_0-auc:0.86913	validation_1-auc:0.84779
# [76]	validation_0-auc:0.86926	validation_1-auc:0.84801
# [77]	validation_0-auc:0.86941	validation_1-auc:0.84815
# [78]	validation_0-auc:0.86962	validation_1-auc:0.84812
# [79]	validation_0-auc:0.86969	validation_1-auc:0.84823
# [80]	validation_0-auc:0.86989	validation_1-auc:0.84825
# [81]	validation_0-auc:0.86997	validation_1-auc:0.84826
# [82]	validation_0-auc:0.87048	validation_1-auc:0.84853
# [83]	validation_0-auc:0.87061	validation_1-auc:0.84850
# [84]	validation_0-auc:0.87071	validation_1-auc:0.84854
# [85]	validation_0-auc:0.87101	validation_1-auc:0.84847
# [86]	validation_0-auc:0.87120	validation_1-auc:0.84849
# [87]	validation_0-auc:0.87128	validation_1-auc:0.84855
# [88]	validation_0-auc:0.87139	validation_1-auc:0.84862
# [89]	validation_0-auc:0.87141	validation_1-auc:0.84862
# [90]	validation_0-auc:0.87153	validation_1-auc:0.84865
# [91]	validation_0-auc:0.87164	validation_1-auc:0.84861
# [92]	validation_0-auc:0.87170	validation_1-auc:0.84848
# [93]	validation_0-auc:0.87177	validation_1-auc:0.84843
# [94]	validation_0-auc:0.87187	validation_1-auc:0.84859
# [95]	validation_0-auc:0.87208	validation_1-auc:0.84861
# [96]	validation_0-auc:0.87235	validation_1-auc:0.84849
# [97]	validation_0-auc:0.87256	validation_1-auc:0.84843
# [98]	validation_0-auc:0.87263	validation_1-auc:0.84844
# [99]	validation_0-auc:0.87302	validation_1-auc:0.84828
# [100]	validation_0-auc:0.87328	validation_1-auc:0.84809
# [101]	validation_0-auc:0.87333	validation_1-auc:0.84812
# [102]	validation_0-auc:0.87354	validation_1-auc:0.84822
# [103]	validation_0-auc:0.87371	validation_1-auc:0.84803
# [104]	validation_0-auc:0.87387	validation_1-auc:0.84781
# [105]	validation_0-auc:0.87407	validation_1-auc:0.84783
# [106]	validation_0-auc:0.87418	validation_1-auc:0.84787
# [107]	validation_0-auc:0.87443	validation_1-auc:0.84774
# [108]	validation_0-auc:0.87475	validation_1-auc:0.84793
# [109]	validation_0-auc:0.87493	validation_1-auc:0.84809
# [110]	validation_0-auc:0.87505	validation_1-auc:0.84807
# [111]	validation_0-auc:0.87548	validation_1-auc:0.84818
# [112]	validation_0-auc:0.87554	validation_1-auc:0.84809
# [113]	validation_0-auc:0.87573	validation_1-auc:0.84816
# [114]	validation_0-auc:0.87600	validation_1-auc:0.84838
# [115]	validation_0-auc:0.87630	validation_1-auc:0.84835
# [116]	validation_0-auc:0.87639	validation_1-auc:0.84842
# [117]	validation_0-auc:0.87644	validation_1-auc:0.84845
# [118]	validation_0-auc:0.87650	validation_1-auc:0.84844
# [119]	validation_0-auc:0.87655	validation_1-auc:0.84842
# [120]	validation_0-auc:0.87663	validation_1-auc:0.84859
# [121]	validation_0-auc:0.87666	validation_1-auc:0.84862
# [122]	validation_0-auc:0.87693	validation_1-auc:0.84854
# [123]	validation_0-auc:0.87697	validation_1-auc:0.84859
# [124]	validation_0-auc:0.87708	validation_1-auc:0.84851
# [125]	validation_0-auc:0.87714	validation_1-auc:0.84852
# [126]	validation_0-auc:0.87753	validation_1-auc:0.84846
# [127]	validation_0-auc:0.87779	validation_1-auc:0.84846
# [128]	validation_0-auc:0.87802	validation_1-auc:0.84858
# [129]	validation_0-auc:0.87825	validation_1-auc:0.84859
# [130]	validation_0-auc:0.87846	validation_1-auc:0.84836
# [131]	validation_0-auc:0.87848	validation_1-auc:0.84832
# [132]	validation_0-auc:0.87856	validation_1-auc:0.84828
# [133]	validation_0-auc:0.87861	validation_1-auc:0.84827
# [134]	validation_0-auc:0.87887	validation_1-auc:0.84814
# [135]	validation_0-auc:0.87917	validation_1-auc:0.84785
# [136]	validation_0-auc:0.87930	validation_1-auc:0.84792
# [137]	validation_0-auc:0.87934	validation_1-auc:0.84796
# [138]	validation_0-auc:0.87937	validation_1-auc:0.84802
# [139]	validation_0-auc:0.87941	validation_1-auc:0.84800
# [140]	validation_0-auc:0.87948	validation_1-auc:0.84797
# [141]	validation_0-auc:0.87959	validation_1-auc:0.84794
# [142]	validation_0-auc:0.87980	validation_1-auc:0.84790
# [143]	validation_0-auc:0.88009	validation_1-auc:0.84796
# [144]	validation_0-auc:0.88053	validation_1-auc:0.84808
# [145]	validation_0-auc:0.88075	validation_1-auc:0.84808
# [146]	validation_0-auc:0.88082	validation_1-auc:0.84812
# [147]	validation_0-auc:0.88107	validation_1-auc:0.84807
# [148]	validation_0-auc:0.88136	validation_1-auc:0.84789
# [149]	validation_0-auc:0.88142	validation_1-auc:0.84789
# [150]	validation_0-auc:0.88157	validation_1-auc:0.84789
# [151]	validation_0-auc:0.88177	validation_1-auc:0.84772
# [152]	validation_0-auc:0.88210	validation_1-auc:0.84784
# [153]	validation_0-auc:0.88216	validation_1-auc:0.84784
# [154]	validation_0-auc:0.88236	validation_1-auc:0.84786
# [155]	validation_0-auc:0.88241	validation_1-auc:0.84787
# [156]	validation_0-auc:0.88246	validation_1-auc:0.84779
# [157]	validation_0-auc:0.88252	validation_1-auc:0.84780
# [158]	validation_0-auc:0.88254	validation_1-auc:0.84778
# [159]	validation_0-auc:0.88263	validation_1-auc:0.84772
# [160]	validation_0-auc:0.88292	validation_1-auc:0.84757
# [161]	validation_0-auc:0.88315	validation_1-auc:0.84749
# [162]	validation_0-auc:0.88352	validation_1-auc:0.84767
# [163]	validation_0-auc:0.88360	validation_1-auc:0.84765
# [164]	validation_0-auc:0.88376	validation_1-auc:0.84774
# [165]	validation_0-auc:0.88400	validation_1-auc:0.84785
# [166]	validation_0-auc:0.88413	validation_1-auc:0.84774
# [167]	validation_0-auc:0.88427	validation_1-auc:0.84774
# [168]	validation_0-auc:0.88443	validation_1-auc:0.84764
# [169]	validation_0-auc:0.88446	validation_1-auc:0.84768
# [170]	validation_0-auc:0.88469	validation_1-auc:0.84773
# [171]	validation_0-auc:0.88480	validation_1-auc:0.84763
# [172]	validation_0-auc:0.88486	validation_1-auc:0.84753
# [173]	validation_0-auc:0.88514	validation_1-auc:0.84741
# [174]	validation_0-auc:0.88522	validation_1-auc:0.84741
# [175]	validation_0-auc:0.88528	validation_1-auc:0.84735
# [176]	validation_0-auc:0.88532	validation_1-auc:0.84733
# [177]	validation_0-auc:0.88543	validation_1-auc:0.84739
# [178]	validation_0-auc:0.88554	validation_1-auc:0.84724
# [179]	validation_0-auc:0.88568	validation_1-auc:0.84724
# [180]	validation_0-auc:0.88589	validation_1-auc:0.84721
# [181]	validation_0-auc:0.88620	validation_1-auc:0.84731
# [182]	validation_0-auc:0.88636	validation_1-auc:0.84734
# [183]	validation_0-auc:0.88657	validation_1-auc:0.84723
# [184]	validation_0-auc:0.88668	validation_1-auc:0.84723
# [185]	validation_0-auc:0.88673	validation_1-auc:0.84715
# [186]	validation_0-auc:0.88678	validation_1-auc:0.84708
# [187]	validation_0-auc:0.88686	validation_1-auc:0.84695
# [188]	validation_0-auc:0.88688	validation_1-auc:0.84694
# [189]	validation_0-auc:0.88692	validation_1-auc:0.84693
# ROC AUC: 0.8238

# %%
xgb_roc_score = roc_auc_score(y_test, xgb_clf.predict_proba(X_test)[:,1])
print('ROC AUC: {0:.4f}'.format(xgb_roc_score))
# Out:
# ROC AUC: 0.8238

# %%
# 전체 데이터 학습
xgb_clf =  XGBClassifier(n_estimators=1000,
                        max_depth=int(best['max_depth']),
                        min_child_weight=int(best['min_child_weight']), 
                        colsample_bytree=best['colsample_bytree'],
                        learning_rate=best['learning_rate'],
                        early_stopping_rounds=100, 
                        eval_metric="auc"
                        )

# evaluation metric을 auc로, early stopping은 100 으로 설정하고 학습 수행. 
xgb_clf.fit(X_features_Q, y_labels, eval_set=[(X_val, y_val)])

xgb_roc_score = roc_auc_score(y_labels, xgb_clf.predict_proba(X_features_Q)[:,1])
print('ROC AUC: {0:.4f}'.format(xgb_roc_score))
# Out:
# [0]	validation_0-auc:0.82646
# [1]	validation_0-auc:0.82841
# [2]	validation_0-auc:0.82578
# [3]	validation_0-auc:0.83230
# [4]	validation_0-auc:0.83486
# [5]	validation_0-auc:0.83733
# [6]	validation_0-auc:0.83767
# [7]	validation_0-auc:0.83906
# [8]	validation_0-auc:0.83701
# [9]	validation_0-auc:0.84225
# [10]	validation_0-auc:0.84436
# [11]	validation_0-auc:0.84579
# [12]	validation_0-auc:0.84699
# [13]	validation_0-auc:0.84750
# [14]	validation_0-auc:0.84800
# [15]	validation_0-auc:0.84879
# [16]	validation_0-auc:0.84926
# [17]	validation_0-auc:0.84966
# [18]	validation_0-auc:0.84998
# [19]	validation_0-auc:0.85054
# [20]	validation_0-auc:0.85146
# [21]	validation_0-auc:0.85194
# [22]	validation_0-auc:0.85251
# [23]	validation_0-auc:0.85314
# [24]	validation_0-auc:0.85353
# [25]	validation_0-auc:0.85428
# [26]	validation_0-auc:0.85469
# [27]	validation_0-auc:0.85498
# [28]	validation_0-auc:0.85532
# [29]	validation_0-auc:0.85575
# [30]	validation_0-auc:0.85616
# [31]	validation_0-auc:0.85685
# [32]	validation_0-auc:0.85724
# [33]	validation_0-auc:0.85782
# [34]	validation_0-auc:0.85832
# [35]	validation_0-auc:0.85881
# [36]	validation_0-auc:0.85906
# [37]	validation_0-auc:0.85999
# [38]	validation_0-auc:0.86005
# [39]	validation_0-auc:0.86036
# [40]	validation_0-auc:0.86080
# [41]	validation_0-auc:0.86095
# [42]	validation_0-auc:0.86117
# [43]	validation_0-auc:0.86160
# [44]	validation_0-auc:0.86165
# [45]	validation_0-auc:0.86166
# [46]	validation_0-auc:0.86200
# [47]	validation_0-auc:0.86248
# [48]	validation_0-auc:0.86271
# [49]	validation_0-auc:0.86296
# [50]	validation_0-auc:0.86332
# [51]	validation_0-auc:0.86351
# [52]	validation_0-auc:0.86389
# [53]	validation_0-auc:0.86420
# [54]	validation_0-auc:0.86445
# [55]	validation_0-auc:0.86453
# [56]	validation_0-auc:0.86484
# [57]	validation_0-auc:0.86514
# [58]	validation_0-auc:0.86532
# [59]	validation_0-auc:0.86555
# [60]	validation_0-auc:0.86576
# [61]	validation_0-auc:0.86609
# [62]	validation_0-auc:0.86622
# [63]	validation_0-auc:0.86652
# [64]	validation_0-auc:0.86651
# [65]	validation_0-auc:0.86680
# [66]	validation_0-auc:0.86701
# [67]	validation_0-auc:0.86715
# [68]	validation_0-auc:0.86722
# [69]	validation_0-auc:0.86732
# [70]	validation_0-auc:0.86744
# [71]	validation_0-auc:0.86753
# [72]	validation_0-auc:0.86777
# [73]	validation_0-auc:0.86784
# [74]	validation_0-auc:0.86794
# [75]	validation_0-auc:0.86806
# [76]	validation_0-auc:0.86819
# [77]	validation_0-auc:0.86825
# [78]	validation_0-auc:0.86842
# [79]	validation_0-auc:0.86862
# [80]	validation_0-auc:0.86873
# [81]	validation_0-auc:0.86877
# [82]	validation_0-auc:0.86892
# [83]	validation_0-auc:0.86911
# [84]	validation_0-auc:0.86915
# [85]	validation_0-auc:0.86931
# [86]	validation_0-auc:0.86940
# [87]	validation_0-auc:0.86956
# [88]	validation_0-auc:0.86969
# [89]	validation_0-auc:0.86972
# [90]	validation_0-auc:0.86972
# [91]	validation_0-auc:0.86986
# [92]	validation_0-auc:0.86991
# [93]	validation_0-auc:0.86999
# [94]	validation_0-auc:0.87010
# [95]	validation_0-auc:0.87012
# [96]	validation_0-auc:0.87032
# [97]	validation_0-auc:0.87053
# [98]	validation_0-auc:0.87063
# [99]	validation_0-auc:0.87092
# [100]	validation_0-auc:0.87095
# [101]	validation_0-auc:0.87103
# [102]	validation_0-auc:0.87123
# [103]	validation_0-auc:0.87124
# [104]	validation_0-auc:0.87131
# [105]	validation_0-auc:0.87135
# [106]	validation_0-auc:0.87140
# [107]	validation_0-auc:0.87147
# [108]	validation_0-auc:0.87162
# [109]	validation_0-auc:0.87203
# [110]	validation_0-auc:0.87206
# [111]	validation_0-auc:0.87213
# [112]	validation_0-auc:0.87216
# [113]	validation_0-auc:0.87225
# [114]	validation_0-auc:0.87228
# [115]	validation_0-auc:0.87235
# [116]	validation_0-auc:0.87251
# [117]	validation_0-auc:0.87254
# [118]	validation_0-auc:0.87273
# [119]	validation_0-auc:0.87286
# [120]	validation_0-auc:0.87291
# [121]	validation_0-auc:0.87304
# [122]	validation_0-auc:0.87313
# [123]	validation_0-auc:0.87320
# [124]	validation_0-auc:0.87343
# [125]	validation_0-auc:0.87349
# [126]	validation_0-auc:0.87356
# [127]	validation_0-auc:0.87375
# [128]	validation_0-auc:0.87381
# [129]	validation_0-auc:0.87386
# [130]	validation_0-auc:0.87388
# [131]	validation_0-auc:0.87413
# [132]	validation_0-auc:0.87416
# [133]	validation_0-auc:0.87432
# [134]	validation_0-auc:0.87443
# [135]	validation_0-auc:0.87450
# [136]	validation_0-auc:0.87453
# [137]	validation_0-auc:0.87464
# [138]	validation_0-auc:0.87475
# [139]	validation_0-auc:0.87479
# [140]	validation_0-auc:0.87490
# [141]	validation_0-auc:0.87512
# [142]	validation_0-auc:0.87515
# [143]	validation_0-auc:0.87520
# [144]	validation_0-auc:0.87535
# [145]	validation_0-auc:0.87537
# [146]	validation_0-auc:0.87544
# [147]	validation_0-auc:0.87547
# [148]	validation_0-auc:0.87556
# [149]	validation_0-auc:0.87570
# [150]	validation_0-auc:0.87575
# [151]	validation_0-auc:0.87581
# [152]	validation_0-auc:0.87597
# [153]	validation_0-auc:0.87619
# [154]	validation_0-auc:0.87622
# [155]	validation_0-auc:0.87640
# [156]	validation_0-auc:0.87643
# [157]	validation_0-auc:0.87659
# [158]	validation_0-auc:0.87669
# [159]	validation_0-auc:0.87674
# [160]	validation_0-auc:0.87678
# [161]	validation_0-auc:0.87706
# [162]	validation_0-auc:0.87734
# [163]	validation_0-auc:0.87736
# [164]	validation_0-auc:0.87757
# [165]	validation_0-auc:0.87773
# [166]	validation_0-auc:0.87776
# [167]	validation_0-auc:0.87783
# [168]	validation_0-auc:0.87793
# [169]	validation_0-auc:0.87817
# [170]	validation_0-auc:0.87824
# [171]	validation_0-auc:0.87831
# [172]	validation_0-auc:0.87831
# [173]	validation_0-auc:0.87832
# [174]	validation_0-auc:0.87840
# [175]	validation_0-auc:0.87849
# [176]	validation_0-auc:0.87853
# [177]	validation_0-auc:0.87871
# [178]	validation_0-auc:0.87876
# [179]	validation_0-auc:0.87884
# [180]	validation_0-auc:0.87903
# [181]	validation_0-auc:0.87910
# [182]	validation_0-auc:0.87915
# [183]	validation_0-auc:0.87939
# [184]	validation_0-auc:0.87957
# [185]	validation_0-auc:0.87978
# [186]	validation_0-auc:0.87992
# [187]	validation_0-auc:0.87997
# [188]	validation_0-auc:0.88017
# [189]	validation_0-auc:0.88028
# [190]	validation_0-auc:0.88032
# [191]	validation_0-auc:0.88041
# [192]	validation_0-auc:0.88049
# [193]	validation_0-auc:0.88053
# [194]	validation_0-auc:0.88058
# [195]	validation_0-auc:0.88073
# [196]	validation_0-auc:0.88083
# [197]	validation_0-auc:0.88084
# [198]	validation_0-auc:0.88089
# [199]	validation_0-auc:0.88096
# [200]	validation_0-auc:0.88104
# [201]	validation_0-auc:0.88123
# [202]	validation_0-auc:0.88124
# [203]	validation_0-auc:0.88129
# [204]	validation_0-auc:0.88150
# [205]	validation_0-auc:0.88153
# [206]	validation_0-auc:0.88152
# [207]	validation_0-auc:0.88154
# [208]	validation_0-auc:0.88169
# [209]	validation_0-auc:0.88172
# [210]	validation_0-auc:0.88175
# [211]	validation_0-auc:0.88184
# [212]	validation_0-auc:0.88200
# [213]	validation_0-auc:0.88222
# [214]	validation_0-auc:0.88223
# [215]	validation_0-auc:0.88231
# [216]	validation_0-auc:0.88243
# [217]	validation_0-auc:0.88247
# [218]	validation_0-auc:0.88251
# [219]	validation_0-auc:0.88254
# [220]	validation_0-auc:0.88275
# [221]	validation_0-auc:0.88276
# [222]	validation_0-auc:0.88280
# [223]	validation_0-auc:0.88295
# [224]	validation_0-auc:0.88307
# [225]	validation_0-auc:0.88322
# [226]	validation_0-auc:0.88327
# [227]	validation_0-auc:0.88329
# [228]	validation_0-auc:0.88343
# [229]	validation_0-auc:0.88345
# [230]	validation_0-auc:0.88348
# [231]	validation_0-auc:0.88351
# [232]	validation_0-auc:0.88360
# [233]	validation_0-auc:0.88365
# [234]	validation_0-auc:0.88382
# [235]	validation_0-auc:0.88400
# [236]	validation_0-auc:0.88404
# [237]	validation_0-auc:0.88413
# [238]	validation_0-auc:0.88416
# [239]	validation_0-auc:0.88419
# [240]	validation_0-auc:0.88423
# [241]	validation_0-auc:0.88437
# [242]	validation_0-auc:0.88439
# [243]	validation_0-auc:0.88440
# [244]	validation_0-auc:0.88441
# [245]	validation_0-auc:0.88461
# [246]	validation_0-auc:0.88481
# [247]	validation_0-auc:0.88500
# [248]	validation_0-auc:0.88507
# [249]	validation_0-auc:0.88512
# [250]	validation_0-auc:0.88530
# [251]	validation_0-auc:0.88536
# [252]	validation_0-auc:0.88540
# [253]	validation_0-auc:0.88541
# [254]	validation_0-auc:0.88566
# [255]	validation_0-auc:0.88567
# [256]	validation_0-auc:0.88570
# [257]	validation_0-auc:0.88571
# [258]	validation_0-auc:0.88587
# [259]	validation_0-auc:0.88593
# [260]	validation_0-auc:0.88603
# [261]	validation_0-auc:0.88613
# [262]	validation_0-auc:0.88626
# [263]	validation_0-auc:0.88631
# [264]	validation_0-auc:0.88639
# [265]	validation_0-auc:0.88648
# [266]	validation_0-auc:0.88670
# [267]	validation_0-auc:0.88673
# [268]	validation_0-auc:0.88682
# [269]	validation_0-auc:0.88683
# [270]	validation_0-auc:0.88685
# [271]	validation_0-auc:0.88693
# [272]	validation_0-auc:0.88694
# [273]	validation_0-auc:0.88708
# [274]	validation_0-auc:0.88708
# [275]	validation_0-auc:0.88713
# [276]	validation_0-auc:0.88725
# [277]	validation_0-auc:0.88748
# [278]	validation_0-auc:0.88767
# [279]	validation_0-auc:0.88769
# [280]	validation_0-auc:0.88785
# [281]	validation_0-auc:0.88788
# [282]	validation_0-auc:0.88795
# [283]	validation_0-auc:0.88803
# [284]	validation_0-auc:0.88808
# [285]	validation_0-auc:0.88819
# [286]	validation_0-auc:0.88823
# [287]	validation_0-auc:0.88829
# [288]	validation_0-auc:0.88842
# [289]	validation_0-auc:0.88843
# [290]	validation_0-auc:0.88849
# [291]	validation_0-auc:0.88854
# [292]	validation_0-auc:0.88860
# [293]	validation_0-auc:0.88862
# [294]	validation_0-auc:0.88866
# [295]	validation_0-auc:0.88868
# [296]	validation_0-auc:0.88878
# [297]	validation_0-auc:0.88886
# [298]	validation_0-auc:0.88893
# [299]	validation_0-auc:0.88899
# [300]	validation_0-auc:0.88919
# [301]	validation_0-auc:0.88927
# [302]	validation_0-auc:0.88930
# [303]	validation_0-auc:0.88936
# [304]	validation_0-auc:0.88946
# [305]	validation_0-auc:0.88953
# [306]	validation_0-auc:0.88967
# [307]	validation_0-auc:0.88972
# [308]	validation_0-auc:0.88972
# [309]	validation_0-auc:0.88974
# [310]	validation_0-auc:0.88982
# [311]	validation_0-auc:0.88984
# [312]	validation_0-auc:0.88996
# [313]	validation_0-auc:0.89010
# [314]	validation_0-auc:0.89016
# [315]	validation_0-auc:0.89021
# [316]	validation_0-auc:0.89034
# [317]	validation_0-auc:0.89046
# [318]	validation_0-auc:0.89050
# [319]	validation_0-auc:0.89055
# [320]	validation_0-auc:0.89064
# [321]	validation_0-auc:0.89070
# [322]	validation_0-auc:0.89086
# [323]	validation_0-auc:0.89087
# [324]	validation_0-auc:0.89096
# [325]	validation_0-auc:0.89112
# [326]	validation_0-auc:0.89118
# [327]	validation_0-auc:0.89124
# [328]	validation_0-auc:0.89126
# [329]	validation_0-auc:0.89129
# [330]	validation_0-auc:0.89132
# [331]	validation_0-auc:0.89133
# [332]	validation_0-auc:0.89134
# [333]	validation_0-auc:0.89140
# [334]	validation_0-auc:0.89147
# [335]	validation_0-auc:0.89163
# [336]	validation_0-auc:0.89185
# [337]	validation_0-auc:0.89188
# [338]	validation_0-auc:0.89193
# [339]	validation_0-auc:0.89213
# [340]	validation_0-auc:0.89220
# [341]	validation_0-auc:0.89228
# [342]	validation_0-auc:0.89235
# [343]	validation_0-auc:0.89251
# [344]	validation_0-auc:0.89252
# [345]	validation_0-auc:0.89260
# [346]	validation_0-auc:0.89261
# [347]	validation_0-auc:0.89259
# [348]	validation_0-auc:0.89276
# [349]	validation_0-auc:0.89292
# [350]	validation_0-auc:0.89301
# [351]	validation_0-auc:0.89312
# [352]	validation_0-auc:0.89313
# [353]	validation_0-auc:0.89332
# [354]	validation_0-auc:0.89344
# [355]	validation_0-auc:0.89350
# [356]	validation_0-auc:0.89357
# [357]	validation_0-auc:0.89391
# [358]	validation_0-auc:0.89396
# [359]	validation_0-auc:0.89412
# [360]	validation_0-auc:0.89412
# [361]	validation_0-auc:0.89427
# [362]	validation_0-auc:0.89432
# [363]	validation_0-auc:0.89434
# [364]	validation_0-auc:0.89440
# [365]	validation_0-auc:0.89441
# [366]	validation_0-auc:0.89443
# [367]	validation_0-auc:0.89448
# [368]	validation_0-auc:0.89451
# [369]	validation_0-auc:0.89453
# [370]	validation_0-auc:0.89455
# [371]	validation_0-auc:0.89458
# [372]	validation_0-auc:0.89459
# [373]	validation_0-auc:0.89463
# [374]	validation_0-auc:0.89466
# [375]	validation_0-auc:0.89470
# [376]	validation_0-auc:0.89471
# [377]	validation_0-auc:0.89474
# [378]	validation_0-auc:0.89480
# [379]	validation_0-auc:0.89492
# [380]	validation_0-auc:0.89505
# [381]	validation_0-auc:0.89507
# [382]	validation_0-auc:0.89508
# [383]	validation_0-auc:0.89520
# [384]	validation_0-auc:0.89530
# [385]	validation_0-auc:0.89530
# [386]	validation_0-auc:0.89538
# [387]	validation_0-auc:0.89548
# [388]	validation_0-auc:0.89551
# [389]	validation_0-auc:0.89555
# [390]	validation_0-auc:0.89566
# [391]	validation_0-auc:0.89583
# [392]	validation_0-auc:0.89587
# [393]	validation_0-auc:0.89605
# [394]	validation_0-auc:0.89612
# [395]	validation_0-auc:0.89615
# [396]	validation_0-auc:0.89616
# [397]	validation_0-auc:0.89624
# [398]	validation_0-auc:0.89637
# [399]	validation_0-auc:0.89670
# [400]	validation_0-auc:0.89685
# [401]	validation_0-auc:0.89694
# [402]	validation_0-auc:0.89704
# [403]	validation_0-auc:0.89710
# [404]	validation_0-auc:0.89725
# [405]	validation_0-auc:0.89729
# [406]	validation_0-auc:0.89744
# [407]	validation_0-auc:0.89748
# [408]	validation_0-auc:0.89755
# [409]	validation_0-auc:0.89760
# [410]	validation_0-auc:0.89762
# [411]	validation_0-auc:0.89764
# [412]	validation_0-auc:0.89769
# [413]	validation_0-auc:0.89778
# [414]	validation_0-auc:0.89790
# [415]	validation_0-auc:0.89795
# [416]	validation_0-auc:0.89796
# [417]	validation_0-auc:0.89802
# [418]	validation_0-auc:0.89805
# [419]	validation_0-auc:0.89805
# [420]	validation_0-auc:0.89806
# [421]	validation_0-auc:0.89812
# [422]	validation_0-auc:0.89824
# [423]	validation_0-auc:0.89845
# [424]	validation_0-auc:0.89852
# [425]	validation_0-auc:0.89854
# [426]	validation_0-auc:0.89857
# [427]	validation_0-auc:0.89860
# [428]	validation_0-auc:0.89863
# [429]	validation_0-auc:0.89863
# [430]	validation_0-auc:0.89865
# [431]	validation_0-auc:0.89870
# [432]	validation_0-auc:0.89877
# [433]	validation_0-auc:0.89890
# [434]	validation_0-auc:0.89902
# [435]	validation_0-auc:0.89906
# [436]	validation_0-auc:0.89912
# [437]	validation_0-auc:0.89912
# [438]	validation_0-auc:0.89914
# [439]	validation_0-auc:0.89915
# [440]	validation_0-auc:0.89917
# [441]	validation_0-auc:0.89920
# [442]	validation_0-auc:0.89925
# [443]	validation_0-auc:0.89928
# [444]	validation_0-auc:0.89927
# [445]	validation_0-auc:0.89934
# [446]	validation_0-auc:0.89940
# [447]	validation_0-auc:0.89944
# [448]	validation_0-auc:0.89953
# [449]	validation_0-auc:0.89958
# [450]	validation_0-auc:0.89958
# [451]	validation_0-auc:0.89960
# [452]	validation_0-auc:0.89960
# [453]	validation_0-auc:0.89964
# [454]	validation_0-auc:0.89965
# [455]	validation_0-auc:0.89970
# [456]	validation_0-auc:0.89973
# [457]	validation_0-auc:0.89976
# [458]	validation_0-auc:0.89978
# [459]	validation_0-auc:0.89999
# [460]	validation_0-auc:0.90012
# [461]	validation_0-auc:0.90015
# [462]	validation_0-auc:0.90022
# [463]	validation_0-auc:0.90030
# [464]	validation_0-auc:0.90034
# [465]	validation_0-auc:0.90036
# [466]	validation_0-auc:0.90040
# [467]	validation_0-auc:0.90047
# [468]	validation_0-auc:0.90066
# [469]	validation_0-auc:0.90071
# [470]	validation_0-auc:0.90075
# [471]	validation_0-auc:0.90079
# [472]	validation_0-auc:0.90098
# [473]	validation_0-auc:0.90105
# [474]	validation_0-auc:0.90115
# [475]	validation_0-auc:0.90120
# [476]	validation_0-auc:0.90122
# [477]	validation_0-auc:0.90122
# [478]	validation_0-auc:0.90133
# [479]	validation_0-auc:0.90134
# [480]	validation_0-auc:0.90136
# [481]	validation_0-auc:0.90146
# [482]	validation_0-auc:0.90151
# [483]	validation_0-auc:0.90156
# [484]	validation_0-auc:0.90159
# [485]	validation_0-auc:0.90166
# [486]	validation_0-auc:0.90173
# [487]	validation_0-auc:0.90180
# [488]	validation_0-auc:0.90188
# [489]	validation_0-auc:0.90197
# [490]	validation_0-auc:0.90202
# [491]	validation_0-auc:0.90211
# [492]	validation_0-auc:0.90215
# [493]	validation_0-auc:0.90221
# [494]	validation_0-auc:0.90234
# [495]	validation_0-auc:0.90255
# [496]	validation_0-auc:0.90258
# [497]	validation_0-auc:0.90267
# [498]	validation_0-auc:0.90267
# [499]	validation_0-auc:0.90273
# [500]	validation_0-auc:0.90284
# [501]	validation_0-auc:0.90296
# [502]	validation_0-auc:0.90297
# [503]	validation_0-auc:0.90306
# [504]	validation_0-auc:0.90312
# [505]	validation_0-auc:0.90323
# [506]	validation_0-auc:0.90325
# [507]	validation_0-auc:0.90337
# [508]	validation_0-auc:0.90342
# [509]	validation_0-auc:0.90353
# [510]	validation_0-auc:0.90358
# [511]	validation_0-auc:0.90363
# [512]	validation_0-auc:0.90363
# [513]	validation_0-auc:0.90364
# [514]	validation_0-auc:0.90365
# [515]	validation_0-auc:0.90365
# [516]	validation_0-auc:0.90366
# [517]	validation_0-auc:0.90367
# [518]	validation_0-auc:0.90370
# [519]	validation_0-auc:0.90371
# [520]	validation_0-auc:0.90372
# [521]	validation_0-auc:0.90377
# [522]	validation_0-auc:0.90380
# [523]	validation_0-auc:0.90383
# [524]	validation_0-auc:0.90383
# [525]	validation_0-auc:0.90386
# [526]	validation_0-auc:0.90401
# [527]	validation_0-auc:0.90407
# [528]	validation_0-auc:0.90407
# [529]	validation_0-auc:0.90418
# [530]	validation_0-auc:0.90419
# [531]	validation_0-auc:0.90427
# [532]	validation_0-auc:0.90431
# [533]	validation_0-auc:0.90436
# [534]	validation_0-auc:0.90436
# [535]	validation_0-auc:0.90441
# [536]	validation_0-auc:0.90441
# [537]	validation_0-auc:0.90444
# [538]	validation_0-auc:0.90448
# [539]	validation_0-auc:0.90451
# [540]	validation_0-auc:0.90452
# [541]	validation_0-auc:0.90462
# [542]	validation_0-auc:0.90462
# [543]	validation_0-auc:0.90465
# [544]	validation_0-auc:0.90472
# [545]	validation_0-auc:0.90472
# [546]	validation_0-auc:0.90488
# [547]	validation_0-auc:0.90491
# [548]	validation_0-auc:0.90504
# [549]	validation_0-auc:0.90504
# [550]	validation_0-auc:0.90507
# [551]	validation_0-auc:0.90509
# [552]	validation_0-auc:0.90511
# [553]	validation_0-auc:0.90521
# [554]	validation_0-auc:0.90523
# [555]	validation_0-auc:0.90529
# [556]	validation_0-auc:0.90538
# [557]	validation_0-auc:0.90542
# [558]	validation_0-auc:0.90543
# [559]	validation_0-auc:0.90547
# [560]	validation_0-auc:0.90556
# [561]	validation_0-auc:0.90568
# [562]	validation_0-auc:0.90574
# [563]	validation_0-auc:0.90575
# [564]	validation_0-auc:0.90586
# [565]	validation_0-auc:0.90592
# [566]	validation_0-auc:0.90596
# [567]	validation_0-auc:0.90597
# [568]	validation_0-auc:0.90598
# [569]	validation_0-auc:0.90599
# [570]	validation_0-auc:0.90600
# [571]	validation_0-auc:0.90601
# [572]	validation_0-auc:0.90608
# [573]	validation_0-auc:0.90610
# [574]	validation_0-auc:0.90612
# [575]	validation_0-auc:0.90613
# [576]	validation_0-auc:0.90613
# [577]	validation_0-auc:0.90619
# [578]	validation_0-auc:0.90620
# [579]	validation_0-auc:0.90619
# [580]	validation_0-auc:0.90620
# [581]	validation_0-auc:0.90622
# [582]	validation_0-auc:0.90623
# [583]	validation_0-auc:0.90624
# [584]	validation_0-auc:0.90624
# [585]	validation_0-auc:0.90625
# [586]	validation_0-auc:0.90625
# [587]	validation_0-auc:0.90631
# [588]	validation_0-auc:0.90631
# [589]	validation_0-auc:0.90635
# [590]	validation_0-auc:0.90643
# [591]	validation_0-auc:0.90646
# [592]	validation_0-auc:0.90647
# [593]	validation_0-auc:0.90650
# [594]	validation_0-auc:0.90656
# [595]	validation_0-auc:0.90657
# [596]	validation_0-auc:0.90660
# [597]	validation_0-auc:0.90664
# [598]	validation_0-auc:0.90669
# [599]	validation_0-auc:0.90672
# [600]	validation_0-auc:0.90673
# [601]	validation_0-auc:0.90676
# [602]	validation_0-auc:0.90678
# [603]	validation_0-auc:0.90678
# [604]	validation_0-auc:0.90679
# [605]	validation_0-auc:0.90680
# [606]	validation_0-auc:0.90681
# [607]	validation_0-auc:0.90683
# [608]	validation_0-auc:0.90686
# [609]	validation_0-auc:0.90697
# [610]	validation_0-auc:0.90702
# [611]	validation_0-auc:0.90707
# [612]	validation_0-auc:0.90718
# [613]	validation_0-auc:0.90731
# [614]	validation_0-auc:0.90733
# [615]	validation_0-auc:0.90736
# [616]	validation_0-auc:0.90742
# [617]	validation_0-auc:0.90749
# [618]	validation_0-auc:0.90752
# [619]	validation_0-auc:0.90762
# [620]	validation_0-auc:0.90768
# [621]	validation_0-auc:0.90769
# [622]	validation_0-auc:0.90777
# [623]	validation_0-auc:0.90777
# [624]	validation_0-auc:0.90778
# [625]	validation_0-auc:0.90779
# [626]	validation_0-auc:0.90779
# [627]	validation_0-auc:0.90784
# [628]	validation_0-auc:0.90790
# [629]	validation_0-auc:0.90800
# [630]	validation_0-auc:0.90802
# [631]	validation_0-auc:0.90803
# [632]	validation_0-auc:0.90812
# [633]	validation_0-auc:0.90816
# [634]	validation_0-auc:0.90832
# [635]	validation_0-auc:0.90843
# [636]	validation_0-auc:0.90849
# [637]	validation_0-auc:0.90856
# [638]	validation_0-auc:0.90857
# [639]	validation_0-auc:0.90859
# [640]	validation_0-auc:0.90860
# [641]	validation_0-auc:0.90860
# [642]	validation_0-auc:0.90860
# [643]	validation_0-auc:0.90860
# [644]	validation_0-auc:0.90860
# [645]	validation_0-auc:0.90875
# [646]	validation_0-auc:0.90877
# [647]	validation_0-auc:0.90882
# [648]	validation_0-auc:0.90887
# [649]	validation_0-auc:0.90896
# [650]	validation_0-auc:0.90898
# [651]	validation_0-auc:0.90907
# [652]	validation_0-auc:0.90908
# [653]	validation_0-auc:0.90909
# [654]	validation_0-auc:0.90911
# [655]	validation_0-auc:0.90917
# [656]	validation_0-auc:0.90920
# [657]	validation_0-auc:0.90928
# [658]	validation_0-auc:0.90936
# [659]	validation_0-auc:0.90945
# [660]	validation_0-auc:0.90948
# [661]	validation_0-auc:0.90951
# [662]	validation_0-auc:0.90951
# [663]	validation_0-auc:0.90951
# [664]	validation_0-auc:0.90965
# [665]	validation_0-auc:0.90970
# [666]	validation_0-auc:0.90976
# [667]	validation_0-auc:0.90982
# [668]	validation_0-auc:0.90984
# [669]	validation_0-auc:0.90986
# [670]	validation_0-auc:0.90990
# [671]	validation_0-auc:0.90990
# [672]	validation_0-auc:0.90991
# [673]	validation_0-auc:0.90995
# [674]	validation_0-auc:0.91001
# [675]	validation_0-auc:0.91003
# [676]	validation_0-auc:0.91007
# [677]	validation_0-auc:0.91009
# [678]	validation_0-auc:0.91013
# [679]	validation_0-auc:0.91020
# [680]	validation_0-auc:0.91030
# [681]	validation_0-auc:0.91031
# [682]	validation_0-auc:0.91044
# [683]	validation_0-auc:0.91047
# [684]	validation_0-auc:0.91049
# [685]	validation_0-auc:0.91057
# [686]	validation_0-auc:0.91064
# [687]	validation_0-auc:0.91065
# [688]	validation_0-auc:0.91072
# [689]	validation_0-auc:0.91081
# [690]	validation_0-auc:0.91084
# [691]	validation_0-auc:0.91086
# [692]	validation_0-auc:0.91098
# [693]	validation_0-auc:0.91100
# [694]	validation_0-auc:0.91100
# [695]	validation_0-auc:0.91101
# [696]	validation_0-auc:0.91101
# [697]	validation_0-auc:0.91107
# [698]	validation_0-auc:0.91111
# [699]	validation_0-auc:0.91116
# [700]	validation_0-auc:0.91118
# [701]	validation_0-auc:0.91120
# [702]	validation_0-auc:0.91122
# [703]	validation_0-auc:0.91123
# [704]	validation_0-auc:0.91133
# [705]	validation_0-auc:0.91136
# [706]	validation_0-auc:0.91142
# [707]	validation_0-auc:0.91142
# [708]	validation_0-auc:0.91143
# [709]	validation_0-auc:0.91144
# [710]	validation_0-auc:0.91145
# [711]	validation_0-auc:0.91146
# [712]	validation_0-auc:0.91149
# [713]	validation_0-auc:0.91151
# [714]	validation_0-auc:0.91153
# [715]	validation_0-auc:0.91152
# [716]	validation_0-auc:0.91154
# [717]	validation_0-auc:0.91154
# [718]	validation_0-auc:0.91154
# [719]	validation_0-auc:0.91157
# [720]	validation_0-auc:0.91158
# [721]	validation_0-auc:0.91159
# [722]	validation_0-auc:0.91159
# [723]	validation_0-auc:0.91159
# [724]	validation_0-auc:0.91161
# [725]	validation_0-auc:0.91175
# [726]	validation_0-auc:0.91177
# [727]	validation_0-auc:0.91177
# [728]	validation_0-auc:0.91177
# [729]	validation_0-auc:0.91192
# [730]	validation_0-auc:0.91194
# [731]	validation_0-auc:0.91195
# [732]	validation_0-auc:0.91198
# [733]	validation_0-auc:0.91206
# [734]	validation_0-auc:0.91216
# [735]	validation_0-auc:0.91217
# [736]	validation_0-auc:0.91218
# [737]	validation_0-auc:0.91225
# [738]	validation_0-auc:0.91231
# [739]	validation_0-auc:0.91233
# [740]	validation_0-auc:0.91234
# [741]	validation_0-auc:0.91234
# [742]	validation_0-auc:0.91242
# [743]	validation_0-auc:0.91245
# [744]	validation_0-auc:0.91254
# [745]	validation_0-auc:0.91259
# [746]	validation_0-auc:0.91259
# [747]	validation_0-auc:0.91260
# [748]	validation_0-auc:0.91262
# [749]	validation_0-auc:0.91262
# [750]	validation_0-auc:0.91262
# [751]	validation_0-auc:0.91266
# [752]	validation_0-auc:0.91265
# [753]	validation_0-auc:0.91267
# [754]	validation_0-auc:0.91267
# [755]	validation_0-auc:0.91269
# [756]	validation_0-auc:0.91271
# [757]	validation_0-auc:0.91277
# [758]	validation_0-auc:0.91283
# [759]	validation_0-auc:0.91293
# [760]	validation_0-auc:0.91294
# [761]	validation_0-auc:0.91297
# [762]	validation_0-auc:0.91301
# [763]	validation_0-auc:0.91307
# [764]	validation_0-auc:0.91308
# [765]	validation_0-auc:0.91313
# [766]	validation_0-auc:0.91313
# [767]	validation_0-auc:0.91315
# [768]	validation_0-auc:0.91316
# [769]	validation_0-auc:0.91319
# [770]	validation_0-auc:0.91322
# [771]	validation_0-auc:0.91323
# [772]	validation_0-auc:0.91323
# [773]	validation_0-auc:0.91324
# [774]	validation_0-auc:0.91328
# [775]	validation_0-auc:0.91331
# [776]	validation_0-auc:0.91341
# [777]	validation_0-auc:0.91350
# [778]	validation_0-auc:0.91361
# [779]	validation_0-auc:0.91364
# [780]	validation_0-auc:0.91364
# [781]	validation_0-auc:0.91370
# [782]	validation_0-auc:0.91377
# [783]	validation_0-auc:0.91379
# [784]	validation_0-auc:0.91384
# [785]	validation_0-auc:0.91387
# [786]	validation_0-auc:0.91388
# [787]	validation_0-auc:0.91389
# [788]	validation_0-auc:0.91395
# [789]	validation_0-auc:0.91398
# [790]	validation_0-auc:0.91399
# [791]	validation_0-auc:0.91400
# [792]	validation_0-auc:0.91400
# [793]	validation_0-auc:0.91399
# [794]	validation_0-auc:0.91405
# [795]	validation_0-auc:0.91412
# [796]	validation_0-auc:0.91412
# [797]	validation_0-auc:0.91412
# [798]	validation_0-auc:0.91413
# [799]	validation_0-auc:0.91416
# [800]	validation_0-auc:0.91417
# [801]	validation_0-auc:0.91417
# [802]	validation_0-auc:0.91424
# [803]	validation_0-auc:0.91428
# [804]	validation_0-auc:0.91432
# [805]	validation_0-auc:0.91436
# [806]	validation_0-auc:0.91446
# [807]	validation_0-auc:0.91447
# [808]	validation_0-auc:0.91450
# [809]	validation_0-auc:0.91452
# [810]	validation_0-auc:0.91456
# [811]	validation_0-auc:0.91461
# [812]	validation_0-auc:0.91467
# [813]	validation_0-auc:0.91474
# [814]	validation_0-auc:0.91480
# [815]	validation_0-auc:0.91480
# [816]	validation_0-auc:0.91487
# [817]	validation_0-auc:0.91487
# [818]	validation_0-auc:0.91500
# [819]	validation_0-auc:0.91508
# [820]	validation_0-auc:0.91511
# [821]	validation_0-auc:0.91513
# [822]	validation_0-auc:0.91513
# [823]	validation_0-auc:0.91520
# [824]	validation_0-auc:0.91522
# [825]	validation_0-auc:0.91527
# [826]	validation_0-auc:0.91530
# [827]	validation_0-auc:0.91530
# [828]	validation_0-auc:0.91531
# [829]	validation_0-auc:0.91531
# [830]	validation_0-auc:0.91541
# [831]	validation_0-auc:0.91547
# [832]	validation_0-auc:0.91552
# [833]	validation_0-auc:0.91561
# [834]	validation_0-auc:0.91566
# [835]	validation_0-auc:0.91569
# [836]	validation_0-auc:0.91576
# [837]	validation_0-auc:0.91594
# [838]	validation_0-auc:0.91594
# [839]	validation_0-auc:0.91597
# [840]	validation_0-auc:0.91598
# [841]	validation_0-auc:0.91606
# [842]	validation_0-auc:0.91611
# [843]	validation_0-auc:0.91611
# [844]	validation_0-auc:0.91611
# [845]	validation_0-auc:0.91630
# [846]	validation_0-auc:0.91637
# [847]	validation_0-auc:0.91637
# [848]	validation_0-auc:0.91641
# [849]	validation_0-auc:0.91648
# [850]	validation_0-auc:0.91650
# [851]	validation_0-auc:0.91651
# [852]	validation_0-auc:0.91653
# [853]	validation_0-auc:0.91653
# [854]	validation_0-auc:0.91653
# [855]	validation_0-auc:0.91654
# [856]	validation_0-auc:0.91654
# [857]	validation_0-auc:0.91656
# [858]	validation_0-auc:0.91659
# [859]	validation_0-auc:0.91661
# [860]	validation_0-auc:0.91663
# [861]	validation_0-auc:0.91665
# [862]	validation_0-auc:0.91665
# [863]	validation_0-auc:0.91680
# [864]	validation_0-auc:0.91683
# [865]	validation_0-auc:0.91683
# [866]	validation_0-auc:0.91690
# [867]	validation_0-auc:0.91692
# [868]	validation_0-auc:0.91696
# [869]	validation_0-auc:0.91700
# [870]	validation_0-auc:0.91704
# [871]	validation_0-auc:0.91704
# [872]	validation_0-auc:0.91704
# [873]	validation_0-auc:0.91706
# [874]	validation_0-auc:0.91709
# [875]	validation_0-auc:0.91711
# [876]	validation_0-auc:0.91714
# [877]	validation_0-auc:0.91720
# [878]	validation_0-auc:0.91726
# [879]	validation_0-auc:0.91726
# [880]	validation_0-auc:0.91727
# [881]	validation_0-auc:0.91727
# [882]	validation_0-auc:0.91732
# [883]	validation_0-auc:0.91733
# [884]	validation_0-auc:0.91734
# [885]	validation_0-auc:0.91736
# [886]	validation_0-auc:0.91738
# [887]	validation_0-auc:0.91740
# [888]	validation_0-auc:0.91742
# [889]	validation_0-auc:0.91746
# [890]	validation_0-auc:0.91747
# [891]	validation_0-auc:0.91751
# [892]	validation_0-auc:0.91751
# [893]	validation_0-auc:0.91756
# [894]	validation_0-auc:0.91760
# [895]	validation_0-auc:0.91760
# [896]	validation_0-auc:0.91769
# [897]	validation_0-auc:0.91771
# [898]	validation_0-auc:0.91774
# [899]	validation_0-auc:0.91779
# [900]	validation_0-auc:0.91784
# [901]	validation_0-auc:0.91787
# [902]	validation_0-auc:0.91787
# [903]	validation_0-auc:0.91790
# [904]	validation_0-auc:0.91795
# [905]	validation_0-auc:0.91797
# [906]	validation_0-auc:0.91801
# [907]	validation_0-auc:0.91802
# [908]	validation_0-auc:0.91803
# [909]	validation_0-auc:0.91805
# [910]	validation_0-auc:0.91805
# [911]	validation_0-auc:0.91810
# [912]	validation_0-auc:0.91811
# [913]	validation_0-auc:0.91811
# [914]	validation_0-auc:0.91821
# [915]	validation_0-auc:0.91827
# [916]	validation_0-auc:0.91827
# [917]	validation_0-auc:0.91828
# [918]	validation_0-auc:0.91829
# [919]	validation_0-auc:0.91829
# [920]	validation_0-auc:0.91829
# [921]	validation_0-auc:0.91830
# [922]	validation_0-auc:0.91832
# [923]	validation_0-auc:0.91833
# [924]	validation_0-auc:0.91835
# [925]	validation_0-auc:0.91843
# [926]	validation_0-auc:0.91851
# [927]	validation_0-auc:0.91865
# [928]	validation_0-auc:0.91867
# [929]	validation_0-auc:0.91867
# [930]	validation_0-auc:0.91871
# [931]	validation_0-auc:0.91872
# [932]	validation_0-auc:0.91872
# [933]	validation_0-auc:0.91873
# [934]	validation_0-auc:0.91875
# [935]	validation_0-auc:0.91882
# [936]	validation_0-auc:0.91882
# [937]	validation_0-auc:0.91881
# [938]	validation_0-auc:0.91882
# [939]	validation_0-auc:0.91886
# [940]	validation_0-auc:0.91892
# [941]	validation_0-auc:0.91893
# [942]	validation_0-auc:0.91896
# [943]	validation_0-auc:0.91903
# [944]	validation_0-auc:0.91909
# [945]	validation_0-auc:0.91910
# [946]	validation_0-auc:0.91913
# [947]	validation_0-auc:0.91913
# [948]	validation_0-auc:0.91924
# [949]	validation_0-auc:0.91928
# [950]	validation_0-auc:0.91929
# [951]	validation_0-auc:0.91934
# [952]	validation_0-auc:0.91936
# [953]	validation_0-auc:0.91938
# [954]	validation_0-auc:0.91952
# [955]	validation_0-auc:0.91956
# [956]	validation_0-auc:0.91960
# [957]	validation_0-auc:0.91961
# [958]	validation_0-auc:0.91962
# [959]	validation_0-auc:0.91966
# [960]	validation_0-auc:0.91971
# [961]	validation_0-auc:0.91975
# [962]	validation_0-auc:0.91977
# [963]	validation_0-auc:0.91983
# [964]	validation_0-auc:0.91989
# [965]	validation_0-auc:0.91994
# [966]	validation_0-auc:0.91995
# [967]	validation_0-auc:0.91996
# [968]	validation_0-auc:0.91997
# [969]	validation_0-auc:0.92000
# [970]	validation_0-auc:0.92003
# [971]	validation_0-auc:0.92005
# [972]	validation_0-auc:0.92010
# [973]	validation_0-auc:0.92011
# [974]	validation_0-auc:0.92012
# [975]	validation_0-auc:0.92013
# [976]	validation_0-auc:0.92017
# [977]	validation_0-auc:0.92017
# [978]	validation_0-auc:0.92017
# [979]	validation_0-auc:0.92028
# [980]	validation_0-auc:0.92029
# [981]	validation_0-auc:0.92031
# [982]	validation_0-auc:0.92037
# [983]	validation_0-auc:0.92037
# [984]	validation_0-auc:0.92038
# [985]	validation_0-auc:0.92039
# [986]	validation_0-auc:0.92041
# [987]	validation_0-auc:0.92043
# [988]	validation_0-auc:0.92045
# [989]	validation_0-auc:0.92055
# [990]	validation_0-auc:0.92055
# [991]	validation_0-auc:0.92056
# [992]	validation_0-auc:0.92064
# [993]	validation_0-auc:0.92067
# [994]	validation_0-auc:0.92067
# [995]	validation_0-auc:0.92068
# [996]	validation_0-auc:0.92070
# [997]	validation_0-auc:0.92074
# [998]	validation_0-auc:0.92074
# [999]	validation_0-auc:0.92076
# ROC AUC: 0.9156

# %%
test_result = xgb_clf.predict_proba(test_df_Q)[:,1]

# %%
sample = pd.read_csv('./santander-customer-satisfaction/sample_submission.csv')
sample['TARGET'] = test_result

# %%
sample.to_csv('./result.csv', index=False)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score

def get_clf_eval(y_test, pred=None, pred_proba=None):
    confusion = confusion_matrix( y_test, pred)
    accuracy = accuracy_score(y_test , pred)
    precision = precision_score(y_test , pred)
    recall = recall_score(y_test , pred)
    f1 = f1_score(y_test,pred)
    # ROC-AUC 추가 
    roc_auc = roc_auc_score(y_test, pred_proba)
    print('오차 행렬')
    print(confusion)
    # ROC-AUC print 추가
    print('정확도: {0:.4f}, 정밀도: {1:.4f}, 재현율: {2:.4f},\
    F1: {3:.4f}, AUC:{4:.4f}'.format(accuracy, precision, recall, f1, roc_auc))

# %%
get_clf_eval(y_test, xgb_clf.predict(X_test), xgb_clf.predict_proba(X_test)[:,1])
# Out:
# 오차 행렬
# [[13290  1312]
#  [  349   253]]
# 정확도: 0.8908, 정밀도: 0.1617, 재현율: 0.4203,    F1: 0.2335, AUC:0.7765

# %%
get_clf_eval(y_test, xgb_clf.predict(X_test), xgb_clf.predict_proba(X_test)[:,1])
# Out:
# 오차 행렬
# [[14601     1]
#  [  533    69]]
# 정확도: 0.9649, 정밀도: 0.9857, 재현율: 0.1146,    F1: 0.2054, AUC:0.9086
